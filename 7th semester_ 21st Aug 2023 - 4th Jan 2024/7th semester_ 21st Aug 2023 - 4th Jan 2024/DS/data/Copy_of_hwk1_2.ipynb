# %% [markdown]
# # CS 447 Homework 1 $-$ Language Models & Morphological Transduction
# In this homework we will study some traditional appraoches to a few natural language tasks. First, you will build some n-gram language models on a corpus of Wikipedia articles, and then you will design a finite-state transducer for verb conjugation in Spanish.
#
# This notebook is designed to be run in Google Colab. Navigate to <TT>colab.research.google.com</TT> and upload this notebook. Then follow the instructions in the notebook to do the assignent.
#
# To run the notebook, you will need to connect to a Runtime. For this homework, all you need is a CPU. You can change the runtime by going to <TT>Runtime > Change runtime type</TT> and selecting <TT>None</TT> in the <TT>Hardware Accelerator</TT> field. We encourage you to disconnect from the runtime when you are not using it, as Google Colab can limit your resources if you overuse them.
#
# You can read more about Google Colab at https://research.google.com/colaboratory/faq.html.
#
# We have imported all the libraries you need to do this homework. <b>You should not import any extra libraries.</b> If you do, the autograder will fail to run your code.

# %% [markdown]
# #Part 1: Language Models [60 points]
#
# Here, you will train some <b>n-gram language models</b> on WikiText-2, a corpus of high-quality Wikipedia articles. The dataset was originally introduced in the following paper: https://arxiv.org/pdf/1609.07843v1.pdf. A raw version of the data can easily be viewed here: https://github.com/pytorch/examples/tree/master/word_language_model/data/wikitext-2.
#
# Unfortunately, you have to install the <TT>torchdata</TT> package on the Colab machine in order to access the data. To do this, run the cell below (you may need to click the "Restart Runtime" button when it finishes). You will have to do this every time you return to work on the homework.

# %%
# !pip install torchdata==0.5.1
# !pip install torchtext==0.14.0
# Out:
# Collecting torchdata==0.5.1
#   Downloading torchdata-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.10/dist-packages (from torchdata==0.5.1) (2.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchdata==0.5.1) (2.31.0)
# Collecting portalocker>=2.0.0 (from torchdata==0.5.1)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting torch==1.13.1 (from torchdata==0.5.1)
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1->torchdata==0.5.1) (4.5.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==1.13.1->torchdata==0.5.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 45.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==1.13.1->torchdata==0.5.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==1.13.1->torchdata==0.5.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==1.13.1->torchdata==0.5.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 58.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->torchdata==0.5.1) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->torchdata==0.5.1) (0.41.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchdata==0.5.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchdata==0.5.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchdata==0.5.1) (2023.7.22)
# Installing collected packages: portalocker, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, torch, torchdata
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Attempting uninstall: torchdata
#     Found existing installation: torchdata 0.6.1
#     Uninstalling torchdata-0.6.1:
#       Successfully uninstalled torchdata-0.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchtext 0.15.2 requires torchdata==0.6.1, but you have torchdata 0.5.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 portalocker-2.7.0 torch-1.13.1 torchdata-0.5.1
# Collecting torchtext==0.14.0
#   Downloading torchtext-0.14.0-cp310-cp310-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.14.0) (4.66.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.14.0) (2.31.0)
# Collecting torch==1.13.0 (from torchtext==0.14.0)
#   Downloading torch-1.13.0-cp310-cp310-manylinux1_x86_64.whl (890.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.1/890.1 MB 604.2 kB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.14.0) (1.23.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.0->torchtext==0.14.0) (4.5.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.0->torchtext==0.14.0) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.0->torchtext==0.14.0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.0->torchtext==0.14.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch==1.13.0->torchtext==0.14.0) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchtext==0.14.0) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchtext==0.14.0) (0.41.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.14.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.14.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.14.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.14.0) (2023.7.22)
# Installing collected packages: torch, torchtext
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1
#     Uninstalling torch-1.13.1:
#       Successfully uninstalled torch-1.13.1
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.2
#     Uninstalling torchtext-0.15.2:
#       Successfully uninstalled torchtext-0.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.13.0 which is incompatible.
# torchdata 0.5.1 requires torch==1.13.1, but you have torch 1.13.0 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 1.13.0 which is incompatible.
# Successfully installed torch-1.13.0 torchtext-0.14.0

# %% [markdown]
# ## Preprocessing the Data
#
# To make your models more robust, it is necessary to perform some basic preprocessing on the corpora. <i>You do not need to edit this code.</i>
#
# * <b>Sentence splitting:</b>&nbsp;&nbsp;&nbsp;&nbsp;In this homework, we are interested in modeling individual sentences, rather than longer chunks of text such as paragraphs or documents. The WikiTest dataset provides paragraphs; thus, we provide a simple method to identify individual sentences by splitting paragraphs at punctuation tokens (".",  "!",  "?").
#
# * <b>Sentence markers:</b>&nbsp;&nbsp;&nbsp;&nbsp;For both training and testing corpora, each sentence must be surrounded by a start-of-sentence (`<s>`) and end-of-sentence marker (`/s`). These markers will allow your models to generate sentences that have realistic beginnings and endings.
#
# * <b>Unknown words:</b>&nbsp;&nbsp;&nbsp;&nbsp;In order to deal with unknown words in the test corpora, all words that do not appear in the vocabulary must be replaced with a special token for unknown words (`<UNK>`) before estimating your models. The WikiText dataset has already done this, and you can read about the method in the paper above. When unknown words are encountered in the test corpus, they should be treated as that special token instead.
#
# We provide you with preprocessing code here, and you should not modify it.
#
# After the preprocessing, you may assume that all words in the test set appear in the training set, as this code has already replaced the unseen tokens with `<UNK>`.

# %%
# Constants (feel free to use these in your code, but do not change them)
START = "<s>"   # Start-of-sentence token
END = "</s>"    # End-of-sentence-token
UNK = "<UNK>"   # Unknown word token

# %%
### DO NOT EDIT ###

import torchtext
import random
import sys

def preprocess(data, vocab=None):
    final_data = []
    lowercase = "abcdefghijklmnopqrstuvwxyz"
    for paragraph in data:
        paragraph = [x if x != '<unk>' else UNK for x in paragraph.split()]
        if vocab is not None:
            paragraph = [x if x in vocab else UNK for x in paragraph]
        if paragraph == [] or paragraph.count('=') >= 2: continue
        sen = []
        prev_punct, prev_quot = False, False
        for word in paragraph:
            if prev_quot:
                if word[0] not in lowercase:
                    final_data.append(sen)
                    sen = []
                    prev_punct, prev_quot = False, False
            if prev_punct:
                if word == '"':
                    prev_punct, prev_quot = False, True
                else:
                    if word[0] not in lowercase:
                        final_data.append(sen)
                        sen = []
                        prev_punct, prev_quot = False, False
            if word in {'.', '?', '!'}: prev_punct = True
            sen += [word]
        if sen[-1] not in {'.', '?', '!', '"'}: continue # Prevent a lot of short sentences
        final_data.append(sen)
    vocab_was_none = vocab is None
    if vocab is None:
        vocab = set()
    for i in range(len(final_data)):
        final_data[i] = [START] + final_data[i] + [END]
        if vocab_was_none:
            for word in final_data[i]:
                vocab.add(word)
    return final_data, vocab

def getDataset():
    dataset = torchtext.datasets.WikiText2(root='.data', split=('train', 'valid'))
    train_dataset, vocab = preprocess(dataset[0])
    test_dataset, _ = preprocess(dataset[1], vocab)

    return train_dataset, test_dataset

if __name__ == '__main__':
    train_dataset, test_dataset = getDataset()

# %% [markdown]
# Run the next cell to see 10 random sentences of the training data.

# %%
if __name__ == '__main__':
    for x in random.sample(train_dataset, 10):
        print (x)
# Out:
# ['<s>', 'Markgraf', 'was', 'ordered', 'under', 'the', 'provisional', 'name', 'Ersatz', '<UNK>', 'and', 'built', 'at', 'the', 'AG', '<UNK>', 'shipyard', 'in', '<UNK>', 'under', 'construction', 'number', '186', '.', '</s>']
# ['<s>', 'However', ',', 'as', 'the', 'group', "'s", 'Steeltown', 'contract', 'had', 'not', 'yet', 'expired', ',', 'the', 'new', 'contract', 'could', 'not', 'be', 'fully', 'executed', 'until', 'March', '11', ',', '1969', '.', '</s>']
# ['<s>', 'A', 'small', 'circulation', 'remained', 'in', 'the', 'cloud', 'field', 'offshore', 'the', 'northwest', 'coast', 'of', 'Baja', 'California', 'for', 'a', 'few', 'more', 'days', '.', '</s>']
# ['<s>', 'Wetherall', 'was', 'appointed', 'player', '@-@', 'manager', 'on', 'a', 'temporary', 'basis', 'and', 'then', 'for', 'the', 'rest', 'of', 'the', 'season', ',', 'but', 'City', 'were', 'relegated', 'following', 'a', '3', '–', '0', 'defeat', 'to', 'Chesterfield', '.', '</s>']
# ['<s>', 'Within', 'two', 'months', ',', 'most', 'juveniles', 'will', 'have', '<UNK>', 'and', 'gained', 'their', 'first', 'basic', 'plumage', '.', '</s>']
# ['<s>', 'His', 'estate', 'was', 'bequeathed', ',', 'in', 'descending', 'order', 'of', 'choice', ',', 'to', 'the', 'following', ':', '1', ')', 'his', 'daughter', ',', 'Susanna', 'Hall', ';', '2', ')', 'upon', 'Susanna', "'s", 'death', ',', '"', 'to', 'the', 'first', 'sonne', 'of', 'her', '<UNK>', '<UNK>', '<UNK>', '&', 'to', 'the', '<UNK>', 'Males', 'of', 'the', '<UNK>', 'of', 'the', '<UNK>', 'first', '<UNK>', '<UNK>', '<UNK>', '"', ';', '3', ')', 'to', 'Susanna', "'s", 'second', 'son', 'and', 'his', 'male', 'heirs', ';', '4', ')', 'to', 'Susanna', "'s", 'third', 'son', 'and', 'his', 'male', 'heirs', ';', '5', ')', 'to', 'Susanna', "'s", '"', '<UNK>', '...', '<UNK>', '<UNK>', '&', '<UNK>', '<UNK>', '"', 'and', 'their', 'male', 'heirs', ';', '6', ')', 'to', 'Elizabeth', ',', 'Susanna', 'and', 'John', 'Hall', "'s", 'firstborn', ',', 'and', 'her', 'male', 'heirs', ';', '7', ')', 'to', 'Judith', 'and', 'her', 'male', 'heirs', ';', 'or', '8', ')', 'to', 'whatever', 'heirs', 'the', 'law', 'would', 'normally', 'recognise', '.', '</s>']
# ['<s>', 'Outside', 'the', 'castle', "'s", 'entrance', 'was', 'a', '"', 'walled', 'suburb', '"', 'known', 'as', 'a', '<UNK>', ',', 'no', 'trace', 'of', 'which', 'remains', '.', '</s>']
# ['<s>', 'Coal', 'mining', 'operations', 'may', 'have', 'weakened', 'the', 'mountain', "'s", 'internal', 'structure', ',', 'as', 'did', 'a', 'wet', 'winter', 'and', 'cold', 'snap', 'on', 'the', 'night', 'of', 'the', 'disaster', '.', '</s>']
# ['<s>', 'The', 'poem', 'concludes', 'with', 'the', 'narrator', 'giving', 'up', 'on', 'having', 'all', 'three', 'of', 'the', 'figures', 'as', 'part', 'of', 'his', 'life', '.', '</s>']
# ['<s>', 'The', 'penultimate', 'track', ',', '"', '<UNK>', 'Que', 'Si', 'Tu', 'No', '<UNK>', '"', '(', '"', 'For', 'That', 'If', 'You', '<UNK>', "'t", '"', ')', ',', 'asks', 'her', 'boyfriend', 'whether', 'or', 'not', 'she', 'should', 'suffer', 'for', 'him', '.', '</s>']

# %% [markdown]
# ## The LanguageModel Class
#
# You will implement 4 types of language models: a <b>unigram</b> model, a <b>smoothed unigram</b> model, a <b>bigram</b> model, and a <b>smoothed bigram</b> model. Each of the models is worth 15 points and extends the following base class. <b>You do not need to implement anything in this class</b>; you will instead implement each of the following methods in the relevant subclass:
#
# * <b>`__init__(self, trainCorpus)`</b>: Train the language model on `trainCorpus`. This will involve calculating relative frequency estimates according to the type of model you're implementing.
#
# * <b>`generateSentence(self)`</b>: <b>[5 points]</b> Return a sentence that is generated by the language model. It should be a list of the form <TT>[&lt;s&gt;, w<sup>(1)</sup>, ..., w<sup>(n)</sup>, &lt;&sol;s&gt;]</TT>, where each <TT>w<sup>(i)</sup></TT> is a word in your vocabulary (including <TT>&lt;UNK&gt;</TT> but exlcuding <TT>&lt;s&gt;</TT> and <TT>&lt;&sol;s&gt;</TT>). You may assume that <TT>&lt;s&gt;</TT> starts each sentence (with probability $1$). The following words <TT>w<sup>(1)</sup></TT>, ... , <TT>w<sup>(n)</sup></TT>, <TT>&lt;&sol;s&gt;</TT> are generated according to your language model's distribution. Note that the number of words <TT>n</TT> is not fixed; instead, you should stop the sentence as soon as you generate the stop token <TT>&lt;&sol;s&gt;</TT>.
#
# * <b>`getSentenceLogProbability(self, sentence)`</b>: <b>[5 points]</b> Return the <em> logarithm of the probability</em> of <TT>sentence</TT>, which is again a list of the form <TT>[&lt;s&gt;, w<sup>(1)</sup>, ..., w<sup>(n)</sup>, &lt;&sol;s&gt;]</TT>. You should use the natural logarithm $-$ that is, the base-<em>e</em> logarithm. See the note below about performing your calculations in log space.
#
# * <b>`getCorpusPerplexity(self, testCorpus)`</b>: <b>[5 points]</b> You need to compute the perplexity (normalized inverse log probability) of `testCorpus` according to your model. For a corpus $W$ with $N$ words and a bigram model, Jurafsky and Martin tells you to compute perplexity as follows:
#
# $$Perplexity(W) = \Big [ \prod_{i=1}^N \frac{1}{P(w^{(i)}|w^{(i-1)})} \Big ]^{1/N}$$
#
# <b>Implementation Hint:</b> In order to avoid underflow, you will likely need to do all of your calculations in log-space. That is, instead of multiplying probabilities, you should add the logarithms of the probabilities and exponentiate the result:
#
# $$\prod_{i=1}^N P(w^{(i)}|w^{(i-1)}) = \exp\Big (\sum_{i=1}^N \log P(w^{(i)}|w^{(i-1)}) \Big ) $$
#
# Using this property should help you in your implementation of `generateSentence(self)` and `getCorpusPerplexity(self, testCorpus)`.
#
# Feel free to implement helper methods as you wish (either in the base class or in the subclases). <b>But be sure not to change the function signatures of the provided methods</b> (i.e. the function and argument names), or else the autograder will fail.

# %%
import math
import random
from collections import defaultdict

class LanguageModel(object):
    def __init__(self, trainCorpus):
        '''
        Initialize and train the model (i.e. estimate the model's underlying probability
        distribution from the training corpus.)
        '''

        ### DO NOT EDIT ###
        return

    def generateSentence(self):
        '''
        Generate a sentence by drawing words according to the model's probability distribution.
        Note: Think about how to set the length of the sentence in a principled way.
        '''

        ### DO NOT EDIT ###
        raise NotImplementedError("Implement generateSentence in each subclass.")

    def getSentenceLogProbability(self, sentence):
        '''
        Calculate the log probability of the sentence provided.
        '''

        ### DO NOT EDIT ###
        raise NotImplementedError("Implement getSentenceProbability in each subclass.")

    def getCorpusPerplexity(self, testCorpus):
        '''
        Calculate the perplexity of the corpus provided.
        '''

        ### DO NOT EDIT ###
        raise NotImplementedError("Implement getCorpusPerplexity in each subclass.")

    def printSentences(self, n):
        '''
        Prints n sentences generated by your model.
        '''

        ### DO NOT EDIT ###
        for i in range(n):
            sent = self.generateSentence()
            prob = self.getSentenceLogProbability(sent)
            print('Log Probability:', prob , '\tSentence:',sent)

# %% [markdown]
# ## <font color='red'>TODO:</font> Unigram Model [15 points]
#
# Here, you will implement each of the 4 functions described above for an <b>unsmoothed unigram</b> model. The probability distribution of a word is given by $\hat P(w)$.
#
# <font color='green'><b>Hints:</b></font>
# * <font color='green'>You should use a <b>dictionary</b> to map tokens to their unigram counts.</font>
# * <font color='green'>Since you never want to generate the start-of-sentence token `<s>`, you should <b>not</b> include it in your counts.</font>
# * <font color='green'>In general, avoid checking for membership in a list (i.e. avoid `x in lst`). Instead, use sets or dictionaries for this purpose $-$ membership checks are much faster on these data structures.</font>
# * <font color='green'>Do <b>not</b> modify the training or test corpora by using `.append(...)` or `.pop(...)` on them. This will cause unexpected behavior in the autograder tests, which do not expect you to be changing the data.

# %%
class UnigramModel(LanguageModel):
    def __init__(self, trainCorpus):
        self.unigram_counts = {}
        self.total_tokens = 0
        # Training on the corpus
        for sentence in trainCorpus:
          for token in sentence:
            if token != '<s>':
              self.unigram_counts[token] = self.unigram_counts.get(token, 0) + 1
              self.total_tokens += 1
    def generateSentence(self):
        generated_sentence = ["<s>"]
        token = None
        while token != "</s>":
          token = self.generateToken()
          generated_sentence.append(token)
        return generated_sentence


    def generateToken(self):
        sampled_word = random.choice(list(self.unigram_counts.keys()))
        while sampled_word == '<s>':
          sampled_word = random.choice(list(self.unigram_counts.keys()))
        return sampled_word

    def getSentenceLogProbability(self, sentence):
        log_prob = 0
        for token in sentence:
          if token not in self.unigram_counts and token != '<s>':
            # Handling words not in corpus. Probability will be zero.
            return float('-inf')
          elif token != '<s>':
            prob = self.unigram_counts[token] / self.total_tokens
            log_prob += math.log(prob)
        return log_prob

    def getCorpusPerplexity(self, testCorpus):
        total_log_prob = 0
        total_tokens = 0
        for sentence in testCorpus:
          total_log_prob += self.getSentenceLogProbability(sentence)
          total_tokens += len(sentence) - 1
          # Subtracting for <s> token
        return math.exp(-total_log_prob/total_tokens)

# %% [markdown]
# We provide you with a testing function that uses very simple training & test corpora (you could compute probability/perplexity by hand if you wanted to). This is just a <b>sanity check</b> $-$ passing this test does not guarantee you a perfect score in the autograder; this is simply to help you debug your model.

# %%
def sanityCheck(model_type):
    assert model_type in {'unigram', 'bigram', 'smoothed-unigram', 'smoothed-bigram'}

    #	Read in the test corpus
    train_corpus = ["By the Late Classic , a network of few <unk> ( few <unk> ) linked various parts of the city , running for several kilometres through its urban core .",
    "Few people realize how difficult it was to create Sonic 's graphics engine , which allowed for the incredible rate of speed the game 's known for ."]
    test_corpus = ["Classic few parts of the game allowed for few <unk> <unk> incredible city .",
                   "Few <unk> realize the difficult network , which linked the game to Sonic ."]
    train_corpus, _ = preprocess(train_corpus)
    test_corpus, _ = preprocess(test_corpus)
    sentence = preprocess(["Sonic was difficult ."])[0][0]

    # These are the correct answers (don't change them!)
    if model_type == "unigram":
       senprobs = [-19.08542845, -114.5001481799, -108.7963657053, -53.6727664115, -55.4645258807]
       trainPerp, testPerp = 41.3308239726, 38.0122981569
       model = UnigramModel(train_corpus)
    elif model_type == "smoothed-unigram":
       senprobs = [-19.0405293515, -115.3479413049, -108.9114348746, -54.8190029616, -55.8122547346]
       trainPerp, testPerp = 41.9994393615, 39.9531928383
       model = SmoothedUnigramModel(train_corpus)
    elif model_type == "bigram":
       senprobs = [-float('inf'), -10.3450917073, -9.2464794186, -float('inf'), -float('inf')]
       trainPerp, testPerp = 1.3861445461, float('inf')
       model = BigramModel(train_corpus)
    elif model_type == "smoothed-bigram":
       senprobs = [-16.355820202, -76.0026113319, -74.2346475108, -47.2885760372, -51.2730261907]
       trainPerp, testPerp = 12.2307627397, 26.7193157699
       model = SmoothedBigramModelAD(train_corpus)
    else: assert False, 'Invalid model_type'

    print("--- TEST: generateSentence() ---")
    modelSen = model.generateSentence()
    senTestPassed = isinstance(modelSen, list) and len(modelSen) > 1 and isinstance(modelSen[0], str)
    if senTestPassed:
        print ("Test generateSentence() passed!")
    else:
        print ("Test generateSentence() failed; did not return a list of strings...")

    print("\n--- TEST: getSentenceLogProbability(...) ---")
    sentences = [sentence, *train_corpus, *test_corpus]
    failed = 0
    for i in range(len(sentences)):
        sen, correct_prob = sentences[i], senprobs[i]
        prob = round(model.getSentenceLogProbability(sen), 10)
        print("Correct log prob.:", correct_prob, '\tYour log prob.:', prob, '\t', 'PASSED' if prob == correct_prob else 'FAILED', '\t', sen)
        if prob != correct_prob: failed+=1

    if not failed:
        print ("Test getSentenceProbability(...) passed!")
    else:
        print("Test getSentenceProbability(...) failed on", failed, "sentence" if failed == 1 else 'sentences...')

    print("\n--- TEST: getCorpusPerplexity(...) ---")
    train_perp = round(model.getCorpusPerplexity(train_corpus), 10)
    test_perp = round(model.getCorpusPerplexity(test_corpus), 10)

    print("Correct train perp.:", trainPerp, '\tYour train perp.:', train_perp, '\t', 'PASSED' if trainPerp == train_perp else 'FAILED')
    print("Correct test perp.:", testPerp, '\tYour test perp.:', test_perp, '\t', 'PASSED' if testPerp == test_perp else 'FAILED')
    train_passed, test_passed = train_perp == trainPerp, test_perp == testPerp
    if train_passed and test_passed:
        print("Test getCorpusPerplexity(...) passed!")
    else:
        print("Test getCorpusPerplexity(...) failed on", "the training corpus and the testing corpus..." if not train_passed and not test_passed else "the testing corpus..." if not test_passed else "the training corpus...")

if __name__=='__main__':
    sanityCheck('unigram')
# Out:
# --- TEST: generateSentence() ---
# Test generateSentence() passed!
#
# --- TEST: getSentenceLogProbability(...) ---
# Correct log prob.: -19.08542845 	Your log prob.: -19.08542845 	 PASSED 	 ['<s>', 'Sonic', 'was', 'difficult', '.', '</s>']
# Correct log prob.: -114.5001481799 	Your log prob.: -114.5001481799 	 PASSED 	 ['<s>', 'By', 'the', 'Late', 'Classic', ',', 'a', 'network', 'of', 'few', '<UNK>', '(', 'few', '<UNK>', ')', 'linked', 'various', 'parts', 'of', 'the', 'city', ',', 'running', 'for', 'several', 'kilometres', 'through', 'its', 'urban', 'core', '.', '</s>']
# Correct log prob.: -108.7963657053 	Your log prob.: -108.7963657053 	 PASSED 	 ['<s>', 'Few', 'people', 'realize', 'how', 'difficult', 'it', 'was', 'to', 'create', 'Sonic', "'s", 'graphics', 'engine', ',', 'which', 'allowed', 'for', 'the', 'incredible', 'rate', 'of', 'speed', 'the', 'game', "'s", 'known', 'for', '.', '</s>']
# Correct log prob.: -53.6727664115 	Your log prob.: -53.6727664115 	 PASSED 	 ['<s>', 'Classic', 'few', 'parts', 'of', 'the', 'game', 'allowed', 'for', 'few', '<UNK>', '<UNK>', 'incredible', 'city', '.', '</s>']
# Correct log prob.: -55.4645258807 	Your log prob.: -55.4645258807 	 PASSED 	 ['<s>', 'Few', '<UNK>', 'realize', 'the', 'difficult', 'network', ',', 'which', 'linked', 'the', 'game', 'to', 'Sonic', '.', '</s>']
# Test getSentenceProbability(...) passed!
#
# --- TEST: getCorpusPerplexity(...) ---
# Correct train perp.: 41.3308239726 	Your train perp.: 41.3308239726 	 PASSED
# Correct test perp.: 38.0122981569 	Your test perp.: 38.0122981569 	 PASSED
# Test getCorpusPerplexity(...) passed!

# %% [markdown]
# Next, we provide you with another <b>sanity check</b> that trains your model on the *entire* training set, and tests your functions on a small corpus (10 sentences) of *real* test data.
#
# If your code is inefficient, you will likely see that this cell is taking too long. This cell is expected to run in fewer than <b>10 seconds</b>, so if it takes significantly longer than that, you should probably inspect your code for efficiency issues.

# %%
def sanityCheckFullDataset(model_type):
    model = UnigramModel(train_dataset)
    idxes = list(range(75,7500, 800))
    small_test_corpus = [test_dataset[idx] for idx in idxes]
    if model_type == 'unigram':
        senprobs = [-80.7782190984, -174.4769654449, -136.455148267, -225.5890741503, -719.0142129846, -236.350443633, -126.0056604204, -47.3424655612, -47.7775372096, -138.8159941929]
        testPerp = 881.0132848704
        model = UnigramModel(train_dataset)
    elif model_type == 'smoothed-unigram':
        senprobs = [-80.8423009715, -174.5131424172, -136.3181234818, -225.357454098, -719.1543898871, -236.6682968913, -126.1965419509, -47.4369338195, -47.7692144935, -138.542462715]
        testPerp = 881.6105352831
        model = SmoothedUnigramModel(train_dataset)
    elif model_type == 'bigram':
        senprobs = [-float('inf'), -float('inf'), -float('inf'), -float('inf'), -float('inf'), -float('inf'), -float('inf'), -32.1502020637, -float('inf'), -float('inf')]
        testPerp = float ('inf')
        model = BigramModel(train_dataset)
    elif model_type == 'smoothed-bigram':
        senprobs = [-61.3754065648, -141.9754903887, -107.0849366076, -168.4944718788, -619.9409055374, -195.8159911677, -86.3762008156, -32.4764801981, -48.124714509, -124.687107856]
        testPerp = 261.4247123506
        model = SmoothedBigramModelAD(train_dataset)
    else: assert False, 'Invalid model_type'
    print("\n--- TEST: getSentenceLogProbability(...) ---")
    failed = 0
    for i in range(len(small_test_corpus)):
        sen, correct_prob = small_test_corpus[i], senprobs[i]
        prob = round(model.getSentenceLogProbability(sen), 10)
        print("Correct log prob.:", correct_prob, '\tYour log prob.:', prob, '\t', 'PASSED' if prob == correct_prob else 'FAILED', '\t', sen)
        if prob != correct_prob: failed+=1

    if not failed:
        print ("Test getSentenceProbability(...) passed!")
    else:
        print("Test getSentenceProbability(...) failed on", failed, "sentence" if failed == 1 else 'sentences...')

    print("\n--- TEST: getCorpusPerplexity(...) ---")
    test_perp = round(model.getCorpusPerplexity(small_test_corpus), 10)

    print("Correct test perp.:", testPerp, '\tYour test perp.:', test_perp, '\t', 'PASSED' if testPerp == test_perp else 'FAILED')
    test_passed = test_perp == testPerp
    if test_passed:
        print("Test getCorpusPerplexity(...) passed!")
    else:
        print("Test getCorpusPerplexity(...) failed on the testing corpus...")

if __name__=='__main__':
    sanityCheckFullDataset('unigram')
# Out:
# --- TEST: getSentenceLogProbability(...) ---
# Correct log prob.: -80.7782190984 	Your log prob.: -80.7782190984 	 PASSED 	 ['<s>', 'He', 'was', '<UNK>', 'at', '<UNK>', 'College', ',', 'Hobart', ',', 'and', '<UNK>', 'in', '1932', '.', '</s>']
# Correct log prob.: -174.4769654449 	Your log prob.: -174.4769654449 	 PASSED 	 ['<s>', 'Despite', 'being', 'a', 'rare', 'Grade', '9', 'player', 'on', 'the', 'senior', 'team', ',', 'he', 'was', 'one', 'of', 'the', 'Knights', "'", 'two', 'leading', 'rushers', 'that', 'year', '.', '</s>']
# Correct log prob.: -136.455148267 	Your log prob.: -136.455148267 	 PASSED 	 ['<s>', 'Burke', "'s", 'total', 'was', 'a', 'school', 'record', 'for', 'the', 'Big', 'Ten', 'Conference', 'Men', "'s", 'Basketball', 'Tournament', '.', '</s>']
# Correct log prob.: -225.5890741503 	Your log prob.: -225.5890741503 	 PASSED 	 ['<s>', 'The', 'route', 'turns', 'to', 'the', 'northeast', ',', 'passing', 'near', 'the', '<UNK>', 'Leaf', 'Lakes', 'residential', 'development', ',', 'before', 'coming', 'to', 'an', 'interchange', 'with', 'US', '322', '(', 'Black', 'Horse', 'Pike', ')', '.', '</s>']
# Correct log prob.: -719.0142129846 	Your log prob.: -719.0142129846 	 PASSED 	 ['<s>', 'Two', 'points', 'are', 'contested', ':', 'first', ',', 'whether', 'or', 'not', 'the', 'teachings', 'of', 'Scientology', 'qualify', 'as', 'a', '"', 'religion', 'or', '<UNK>', '"', '(', 'Religion', 'or', '<UNK>', ';', 'these', 'are', 'equal', 'before', 'German', 'law', ')', ',', 'and', '<UNK>', ',', 'whether', 'or', 'not', 'these', 'teachings', 'are', 'only', 'used', 'as', 'a', 'pretext', 'for', 'purely', 'commercial', 'activity', ';', 'if', 'the', 'latter', 'were', 'the', 'case', ',', 'this', 'would', 'most', 'likely', 'imply', 'that', 'Scientology', 'would', 'not', 'qualify', 'for', 'protection', 'as', 'a', '"', 'religious', 'or', '<UNK>', 'community', '"', '(', '<UNK>', 'oder', '<UNK>', ')', 'under', 'Article', '4', 'of', 'the', 'German', 'constitution', ',', 'which', 'guarantees', 'the', 'freedom', 'of', 'belief', ',', 'religion', 'and', '<UNK>', '.', '</s>']
# Correct log prob.: -236.350443633 	Your log prob.: -236.350443633 	 PASSED 	 ['<s>', 'He', 'immediately', 'ran', 'into', 'a', 'problem', ':', 'the', 'South', 'Carolina', 'troops', '(', 'militia', 'or', 'the', 'colonial', 'regiments', ')', 'were', 'not', 'on', 'the', 'Continental', 'line', ',', 'and', 'thus', 'not', 'formally', 'under', 'his', 'authority', '.', '</s>']
# Correct log prob.: -126.0056604204 	Your log prob.: -126.0056604204 	 PASSED 	 ['<s>', 'One', 'of', 'them', 'was', 'a', 'bodyguard', 'who', 'was', 'present', 'at', 'the', 'concert', 'but', 'did', 'not', 'see', 'the', 'fall', '.', '</s>']
# Correct log prob.: -47.3424655612 	Your log prob.: -47.3424655612 	 PASSED 	 ['<s>', '<UNK>', 'was', 'relieved', 'on', '17', 'May', '.', '</s>']
# Correct log prob.: -47.7775372096 	Your log prob.: -47.7775372096 	 PASSED 	 ['<s>', 'US', 'Off', 'The', 'Planet', '!', '</s>']
# Correct log prob.: -138.8159941929 	Your log prob.: -138.8159941929 	 PASSED 	 ['<s>', 'The', 'difficulty', 'stems', 'from', 'the', 'relative', 'over', '@-@', 'stabilization', 'of', 'the', '<UNK>', 'cation', 'by', 'electron', 'donation', ',', '<UNK>', '<UNK>', '.', '</s>']
# Test getSentenceProbability(...) passed!
#
# --- TEST: getCorpusPerplexity(...) ---
# Correct test perp.: 881.0132848704 	Your test perp.: 881.0132848704 	 PASSED
# Test getCorpusPerplexity(...) passed!

# %% [markdown]
# Finally, you can train your model on the full WikiText corpus, and evaluate it on the held-out test set.

# %%
def runModel(model_type):
    assert model_type in {'unigram', 'bigram', 'smoothed-unigram', 'smoothed-bigram'}
    # Read the corpora
    if model_type == 'unigram':
        model = UnigramModel(train_dataset)
    elif model_type == 'bigram':
        model = BigramModel(train_dataset)
    elif model_type == 'smoothed-unigram':
        model = SmoothedUnigramModel(train_dataset)
    else:
        model = SmoothedBigramModelAD(train_dataset)

    print("--------- 5 sentences from your model ---------")
    model.printSentences(5)

    print ("\n--------- Corpus Perplexities ---------")
    print ("Training Set:", model.getCorpusPerplexity(train_dataset))
    print ("Testing Set:", model.getCorpusPerplexity(test_dataset))

if __name__=='__main__':
    runModel('unigram')
# Out:
# --------- 5 sentences from your model ---------
# Log Probability: -496423.357119547 	Sentence: ['<s>', 'moulded', 'Seminoles', 'Stelae', '460', 'stadiums', 'doubtful', 'Torchwood', 'fluency', 'CRIA', 'Cajal', 'dent', 'stores', '223', 'facility', 'Capel', 'hospitalization', 'campaigners', 'Legionnaires', 'Djan', 'Mickey', 'Signet', 'Folk', 'HURDAT', 'began', 'reward', 'stingray', 'scaling', 'Fatality', 'Andalee', 'Convict', 'facilitate', 'herders', 'giants', 'Non', 'Jubba', 'desire', 'bodily', 'unfold', 'sun', 'plasma', 'Rebellion', 'Figg', 'twice', 'provisional', '5A', 'asserted', 'Xenon', 'Ashton', 'Awards', 'recruits', 'Wally', 'happen', 'Uist', 'Jeremiah', 'Backed', 'outrageously', 'Kuehn', 'plume', 'nucleophilic', 'turnovers', 'Widmore', 'Juárez', 'Kookaburra', 'Gong', 'directorship', 'Cuney', 'Bessin', 'Hen', 'Fencing', 'fission', 'Apu', 'parties', 'disgusted', 'Mana', 'Rosebery', 'Shiina', 'reinforcements', 'accounting', 'clinic', 'promotion', 'judgment', 'mal', 'Breaking', 'extratropical', 'Susan', 'raiders', 'bestowed', 'apologize', 'refuted', 'Kurfürst', 'patrols', 'Or', 'Io', 'optimistic', 'Tellicherry', 'exiting', 'Tuđman', 'Rhenish', 'tenure', 'crocodile', 'understated', 'patriarchal', 'Stark', 'vegetation', 'ingredient', 'firearms', 'Escorial', 'markers', 'Kay', 'Parasite', 'Pinus', 'completed', 'Rebel', 'turnover', 'tactically', 'ba', 'age', 'convictions', 'Americanism', 'Chan', 'storing', 'angel', 'Lena', 'turbulence', 'Dictionary', 'schedule', 'Shadows', 'Occasionally', 'Americans', 'terminating', 'hurdling', 'colourful', 'Hetherington', 'kidnapping', 'boring', 'riches', 'Arms', 'email', 'craft', 'near', 'flour', 'Lisa', 'Centipede', 'hypothetical', 'Paraguay', 'Sing', 'crossed', 'centralised', 'translations', 'MM', 'Blue', 'deepening', 'Colonial', 'Pavarotti', 'yttrium', 'Girl', 'throne', '1842', 'paths', 'dependence', 'Judea', 'reuse', 'NUJ', 'Title', 'ignorance', 'Jemmappes', 'Newark', 'Nix', 'mediate', 'ballet', 'Moutawakel', 'burrows', 'notified', 'bump', 'cartridge', 'panoramic', 'synthesized', 'Leading', 'Cuautla', 'climbed', 'harm', 'electroplating', 'lice', 'volatile', 'volva', 'Fricke', 'Confucian', 'Doc', 'theirs', '1613', 'names', 'Snelling', 'experiencing', 'Merton', '699', '308', 'Society', 'stern', 'Mill', 'Coupled', 'relented', 'Clinch', 'Träumerei', 'Holdings', 'Ich', 'positional', 'petrol', 'city', 'sociologist', 'lecturer', 'duo', 'Lalande', 'Emperor', 'toxic', 'planetary', 'mistake', 'GB', 'tablets', 'dishes', 'Andalee', 'palatable', 'experts', 'gully', 'mainline', 'Abby', 'pennant', 'Boyle', 'Lamar', 'attempted', 'trawling', 'Kamara', 'posts', 'Y', 'vacuum', 'recast', 'EP', 'Moorside', 'Shaun', 'deceptively', 'Chaytor', 'Rap', 'reprints', 'booth', 'self', 'Eve', 'asiaticus', 'histories', 'curious', 'dismissed', 'fences', 'nets', 'shortlisted', 'Berlioz', 'Slowly', 'supernatural', 'Purdham', 'Farrell', 'superhero', 'Harold', 'hinder', 'ninja', 'basement', 'batters', '″', 'Yourself', 'incidence', 'transforms', 'eka', 'Larrabee', 'bayonets', 'Viva', 'Ha', 'benefits', 'krek', 'plush', 'salary', 'tabloid', 'close', 'Tapes', 'Proteins', 'Hassett', 'Okinawa', 'charmed', 'prompted', 'stibine', 'supervision', 'Terrible', 'stream', 'selecting', 'Waiouru', 'She', 'passing', 'Triumph', 'clinch', 'stagecoaches', 'anglicus', 'TBSA', 'shakes', 'affections', 'rather', 'fascination', 'subplot', 'UCL', 'outbursts', 'Lords', 'Grandmaster', 'Montenegro', 'Adding', 'IR8', 'Leppard', 'thrown', 'interviewing', 'Domenici', 'Goodman', 'Bard', 'Lea', '2015', 'ornaments', 'duck', 'Bayesian', 'wasn', 'Rand', 'These', 'usual', 'clothing', 'grenade', 'Communal', 'vol', 'coasters', 'situations', 'judged', '1139', 'Men', 'sandwich', 'booby', 'must', 'edibility', 'erosion', 'objectors', '1806', 'Roughly', '191', 'grasses', 'Perugia', 'firefight', 'capsule', 'keyed', 'void', 'Oswald', 'rupture', 'consistently', 'think', 'inscribed', 'Miles', 'faded', 'le', 'attempt', 'contemporaries', 'coated', 'notorious', 'Nascarella', 'Bassline', 'NX', 'Fraternal', 'Algiers', 'Southwes ...
# Log Probability: -127064.06563741708 	Sentence: ['<s>', 'blending', 'Un', 'Avatars', 'sovereignty', '19th-', '361', '696', 'Rattle', 'unconventional', 'fluorine', '164', 'stretches', 'outdoor', 'Huang', 'Ramfis', 'Adventures', 'textures', 'Area', 'disciplines', 'Metro', 'legged', 'Wiltshire', 'pump', 'fortunate', 'raising', 'M3', 'principles', 'Hsia', 'delusional', 'totals', 'Henry', 'None', 'Schedeen', 'care', 'Erica', 'typographical', 'Europa', 'Kubica', "'ari", 'views', 'allotted', 'Knope', 'bull', '70th', 'Sutherland', 'Alamgir', 'FITs', 'recreate', 'Tiger', 'Practitioners', 'Godfrey', 'cel', 'laevigatum', 'consider', 'Midlothian', 'McKidd', 'aeroplanes', 'render', 'Cat', 'unwittingly', 'handing', 'cyclotron', 'federal', 'Enrique', 'reductions', '575', 'RanGTP', 'traders', 'quarterdeck', 'Ashes', 'Ohlone', 'cuff', 'commute', 'notes', 'Bahamas', 'Scott', 'Twenty20', 'chemin', 'SAT', 'allergic', 'Azaria', 'Lupton', 'theropods', 'succession', 'Mahamdiyah', 'operas', 'Neversoft', 'auditorium', 'Spector', 'Barack', 'Sudanese', 'nitric', 'WABD', 'silent', 'monk', 'Jade', 'disability', '006', 'pools', 'Mattel', 'Should', 'refusing', 'A320', 'Peshkin', 'physician', 'Harney', 'glacis', 'Abbes', 'Anglesey', 'Able', 'Past', '53', 'ringtone', 'administration', 'mentor', 'plantation', 'Helgenberger', 'goalscoring', 'Sunshine', 'Varina', 'okay', 'baked', '1st', 'RAAF', 'emulate', 'tolerance', 'Dove', 'thieves', 'multicellular', 'nectar', 'stains', 'intermittently', 'Should', 'trapping', 'Pro', 'Tsunami', 'distortions', 'Elo', 'pretends', 'inadvertently', 'Rhode', 'Kenyan', 'explanations', 'melodies', 'Ohio', 'honorific', 'descends', 'Corcoran', 'contestant', 'Brian', 'Integrated', 'disarmed', 'unit', 'earnest', '2003', 'links', 'Kamara', 'fainted', 'Harihara', 'Finds', 'Beni', 'supposed', 'captains', 'forfeits', 'nebulous', 'width', 'electrified', 'Bashir', 'D.J.', 'Fries', 'Increasingly', '323', 'exoplanets', 'Dhangars', '731', 'nightingale', 'corporation', 'replacing', 'asks', 'fixtures', 'Coleby', 'grape', 'institution', 'Weather', 'table', 'Spisevognselskapet', '355', 'deceased', 'Sherborne', 'humans', 'Ferb', 'primary', 'cock', 'Epiphany', 'virus', 'artefacts', 'Dubrovnik', 'seral', 'cabaret', 'brothers', 'unavailable', '625', 'hammer', 'heptathlon', 'Kuwait', 'Amylostereaceae', 'Technically', 'Archbishop', 'Democrats', 'Dwayne', "'être", 'despite', 'libel', 'paranoia', '439', 'applicable', 'Drummer', 'rafts', 'Lanxess', 'Vickers', 'hooks', 'allow', 'now', 'accountability', 'Lucasfilm', 'unearthed', 'behaviors', 'disco', 'utter', 'earthly', 'symbols', '271', 'Clyde', 'Strip', 'Fincher', 'briefed', 'bidder', 'accumulating', 'ჯ', 'Grammer', 'Chronic', 'servants', 'Ibarguren', 'Esarhaddon', 'okay', 'supernova', 'Terror', 'visits', 'Pittsfield', 'moulded', 'Typhoon', 'Variation', 'sociologist', 'Desmond', 'gunshot', 'only', 'unions', 'Lviv', 'speculative', 'penetration', 'severe', 'Reuters', 'renewed', 'gaze', 'Berger', 'coasts', 'Suns', 'falcons', 'readership', 'sexual', 'Galaxy', 'disadvantages', 'lost', 'precise', '203', 'realism', 'Slocum', 'Luftwaffe', 'irresistible', 'Oriente', 'Soval', 'Kendall', 'Q.', 'prepares', 'plagiarized', 'Georgia', 'airliner', 'Centennial', 'Healthcare', 'meantime', 'vocalization', 'heaven', 'reconciliation', 'Tuozhou', 'Blues', 'discontent', 'Fritt', 'protest', 'Britain', 'replace', 'Ilan', 'depend', 'scriptures', 'Everything', 'persons', '1756', 'Friedman', 'Reproduction', 'waterline', 'machismo', 'Pelham', 'lounges', 'primary', 'Officials', 'Jenice', 'Replay', 'action', 'Alexandru', 'stole', 'Are', 'Antarctic', 'gaits', 'Renewed', 'Tag', 'Jazz', 'peach', 'minigame', 'Braathens', 'illness', 'ghosts', '100th', 'punishing', 'Simpsons', 'recalling', 'McCormick', 'analytical', 'harden', 'chiefly', 'predicting', 'tarps', 'Raven', 'Brockman', 'national', 'insurgent', 'rains', 'Number', 'Stott', 'database', 'Cop', 'Nc3', '971', 'taxiing', 'Theorist', 'Fur', 'declares', 'philosophically', 'embedded', 'emotion' ...
# Log Probability: -89804.68893077891 	Sentence: ['<s>', 'announced', 'spawned', 'systems', 'Craig', 'pallium', 'barges', 'percentages', 'carrier', 'argues', 'understory', 'caricatures', 'prestige', 'supreme', 'torpedo', 'Picpoul', 'Destroyer', 'Dvorak', 'speaking', 'Jarrah', 'motorised', 'Untold', 'Alma', 'scarce', 'Caro', '1890', 'pareiasaur', 'benefits', 'Schedule', 'nowhere', 'stint', 'abolitionist', 'occupies', 'If', 'Papa', 'Poole', 'volva', 'shrimp', 'processing', 'Mifune', '1120', 'romance', 'Kirkpatrick', 'Christi', 'Pelusium', 'ASTRA', 'Essential', 'Citizen', 'Leeds', 'questioning', 'fondly', 'Morley', 'interfere', 'opera', 'resolute', 'Hibbing', 'sensations', 'emblem', '200', 'Stacee', 'Abrahamic', 'amended', 'Shoe', 'Batson', 'flared', 'UM', 'Ryder', 'envious', 'Denmark', 'Jovi', 'Zone', 'decrease', 'Claudius', 'Karan', 'filly', 'disciple', 'Solitude', 'extras', 'incompletely', 'Newgate', 'industrialist', 'Liberals', 'astonishing', 'dissenting', 'Desktop', 'Kokanee', 'sickly', 'progress', 'Xi', 'layered', 'urn', 'outdated', 'enclosing', 'Metallurgical', '1164', 'Neserkauhor', 'stresses', 'Obo', 'Porter', 'Mrs', 'detonated', 'kidnaps', 'Lumber', 'fuelled', 'Østerdalen', 'crowd', 'lordship', 'Concerned', 'distorted', 'Anubis', 'Suvarnabhumi', 'American', 'albums', 'Fire', 'tourism', 'nut', 'lives', 'Syrian', 'invades', 'Newcastle', 'meters', 'Nizam', 'Morrow', 'Plains', 'parietal', 'elevated', 'elect', 'ā', 'ecosystems', 'drunken', 'Elmore', 'rebuilding', 'yardage', 'patronym', 'English', 'Northeast', 'Dax', 'lesbian', 'Shyam', 'hetman', 'converting', 'incense', 'complete', 'Telescope', 'staffed', 'Dion', 'Levant', 'wizard', 'irritating', 'Rzepecki', 'subterranean', 'salaries', 'turnover', 'Gregg', 'Sclerodermatineae', 'showering', 'Hey', 'crashed', 'monitors', 'Hassett', 'Bailey', 'cable', 'grasped', 'Korvettenkapitän', 'Tracy', 'inserted', 'telluride', 'blacksmiths', 'Richdale', 'Shaggy', 'yourself', 'padding', '13400', 'Karnow', 'excavation', 'Study', 'Specimens', 'Older', 'massacred', 'weaponry', 'stretch', 'Machines', 'find', 'Laz', 'solitaires', 'moot', 'transitional', 'deeming', 'realize', 'Draws', '1628', '571', 'pots', 'buoy', 'considers', 'Stevens', 'Frontier', 'brunt', 'Baker', 'hairstyles', 'pedigree', 'Nilsson', 'slim', 'joins', 'Commentators', 'Tor', 'Valentine', 'Stein', 'premieres', 'Shabtai', 'sell', 'confluence', 'rich', 'narial', 'vanity', 'ABC', 'Dương', 'reagents', 'meanwhile', 'gun', 'Compounds', 'supposedly', 'instinctively', 'hierarchical', 'catalysis', 'distinguished', 'Found', 'sorting', 'door', 'Berengaria', '060', 'savage', 'outline', 'trouble', 'Pringle', 'But', 'Odyssey', 'migrating', 'Rural', 'editors', 'Mac', 'searched', 'stunt', 'rider', 'incredible', 'Montana', 'boosted', 'units', 'coffin', 'arts', 'ambushed', 'hold', 'Maroon', 'persistence', 'divergence', 'wounding', 'Protoceratops', 'Hamra', 'belonged', 'radically', 'dependable', 'Boonyaratkalin', 'Grants', 'Eternia', '1593', 'whiskey', 'fibrous', 'plague', 'Lisle', 'Zanzibar', '42', 'Saqqara', 'Jayatilleke', 'immense', 'changeup', 'picture', 'finer', 'Causeway', 'vague', 'BANES', 'minds', 'consists', 'meaningless', 'animators', 'battering', 'Het', 'Thomas', 'friendly', 'militants', 'thirteen', 'Pistons', 'sealing', 'navigating', 'Fishhook', 'failed', 'homemaker', 'assortment', 'Amie', 'IRA', 'Lanka', 'showering', 'consultant', 'reacting', 'grizzly', 'Merit', 'labeling', 'donors', 'Meter', 'missionaries', 'superstar', '〉', 'Sultanate', 'milking', 'Communal', '1946', 'yellowish', 'Fruitbodies', 'humiliating', 'liaison', 'Algonquin', 'solves', 'offices', 'Surgeon', 'Commenting', 'Brentford', 'delivering', 'workforce', 'reliant', 'lessen', 'notebook', 'rough', '1934', '33rd', 'buttresses', 'adverts', 'thou', 'nature', 'Mundo', 'roadblock', 'hold', 'Ajuran', 'disorders', 'deposit', 'digital', 'destruction', 'declare', 'progenitor', 'pain', 'Moscow', '750th', 'Karachi', 'e.g.', 'Weekend', '1567', 'facades', 'Levy', 'Stegosauria', 'antiqui ...
# Log Probability: -58595.64586204151 	Sentence: ['<s>', 'imitating', 'Warm', 'HaMifratz', 'gentle', 'Artist', 'Velvet', 'significantly', 'Roger', 'priest', 'implicitly', 'courtroom', 'appraisal', 'dishes', 'attractions', 'laborers', 'term', 'Madero', 'extending', "'l", 'yacht', 'aggravated', 'whereby', 'someone', 'Montagne', 'Western', 'XFX', 'cadets', 'scorers', 'grassland', 'Uno', 'calculator', 'Legion', 'Sister', 'flood', 'Inquiry', 'generic', 'anonymous', 'Østerdalen', 'Kamaludiningrat', 'Freud', 'basket', 'Marathi', 'Jie', 'Irish', 'spiders', 'Norton', 'used', 'Timbo', 'Segersäll', 'Persons', 'Marathi', 'Valencia', 'should', 'discography', 'Klecksel', 'crouch', '245', 'strata', 'Wave', 'gross', 'Djedkare', 'genetics', 'Wilcox', 'Outstanding', 'defied', 'Krypton', 'climb', 'Christ', 'As', 'endless', 'Dick', 'supervisor', '1946', 'stream', 'particle', 'Martínez', 'Climate', 'unwilling', 'sadness', 'Attenborough', 'incentive', 'morels', 'fluorescent', 'F.', 'pastry', 'dispatching', 'Raja', 'brunette', 'citations', 'simulator', '72nd', 'stepmother', 'feed', 'Pinus', 'soloist', 'slippage', 'defenseman', 'grand', 'Atum', 'paving', '1933', 'Sainz', 'Winning', 'celebratory', 'woodpeckers', 'crossed', 'Jessica', 'Hindu', 'Crisis', 'Huang', 'prone', 'Rivers', 'certificate', 'parishioners', 'WrestleMania', 'Lawn', 'industries', 'May', 'guides', 'Victory', 'influenced', 'Music', 'smugglers', 'waist', 'Congo', 'Yours', 'Progress', 'standing', '738', 'Torre', 'robe', 'Barbicane', 'Third', 'Hutzel', 'grows', 'revivals', 'concessions', 'ramifications', 'beginnings', 'melting', 'Rathlin', 'cab', 'Arora', 'Almost', 'elves', 'Everywhere', 'stations', 'Jowhar', 'His', 'Yukizuki', 'tri', 'Motzkin', 'believing', 'sector', 'Dante', '1265', 'Northwestern', 'Layne', 'Increasing', 'protest', 'Fernando', 'Bosnia', '23', 'sinister', 'constituency', 'Amjad', 'chailletii', 'suppliers', 'shake', 'mailings', 'corporal', 'arable', 'Ride', 'fished', 'Alvin', 'Weevil', 'climbed', 'Opera', 'Halladay', 'Randall', '1763', 'Colombia', 'Comptroller', 'Blu', 'Limerick', 'religiously', 'albedo', 'within', 'Out', 'Frankfurt', 'intention', 'edit', 'Bosnian', 'Empty', 'Fortunately', 'Beattie', 'astronauts', 'Pollard', 'unreliable', 'martial', 'JP', 'profile', 'region', 'blackish', '1123', 'Rules', 'Portrait', 'commandment', 'peer', 'Daun', 'Vicarious', 'clearing', 'swell', 'ferry', 'Diamonds', 'posthumous', 'bid', 'Contactmusic.com', 'blatant', 'Brady', 'worshippers', 'To', 'screenwriting', 'aisles', 'Gupta', 'throw', 'cooks', 'fullerene', '1643', 'Petersburg', 'shrinking', 'quarterdeck', 'Scully', 'Sinai', 'cooked', 'Jamaaladeen', 'Auschwitz', 'intestines', 'festival', 'whitish', '373', 'Oswalt', 'divines', 'foothills', 'camels', 'Tremellogaster', 'yourself', 'sanctuaries', 'leaned', '395', '1596', 'typists', 'orchids', 'Species', 'anachronism', 'liable', 'rotating', 'matrix', 'eyelids', 'pulled', 'Car', 'dissent', 'divisive', '1947', 'Broadcast', 'anime', 'Guru', 'Castro', 'Psittacosaurus', 'Rose', 'cruel', 'ageing', 'Hamel', 'explaining', 'commemorates', 'inspirations', 'victory', 'Calthrop', 'Perkins', 'Situated', 'Chapels', 'deepened', 'Would', 'cavity', 'tentatively', 'Narron', 'Hibari.Ch.', 'violations', 'unpopularity', 'netting', 'our', 'poorest', 'Algy', 'lambs', 'della', 'flea', 'slightly', 'SAS', 'Issue', 'ninety', 'Forced', 'terminus', 'tonnes', 'bead', 'players', 'Animation', 'hearts', 'rapes', '277', 'figurines', 'protagonist', '217', 'disgraced', 'César', 'THE', 'discovers', 'eukaryotic', 'glands', 'impaired', 'Rankin', 'Ustaše', 'Rederi', 'chief', 'Sands', 'Cave', '1999', 'dispersal', 'ecoregion', 'predator', 'Junkers', 'display', 'blinded', 'recurring', 'Wear', 'Hereford', 'debris', 'remodeled', 'Org', 'Abby', 'revisiting', 'editor', 'Demon', 'dodo', 'prerequisite', '217', 'win', 'Amy', 'Kash', 'Moriarty', 'Fischer', 'battleline', 'wealthiest', 'Found', 'initiating', 'nasal', 'Neville', 'Almina', 'Glastonbury', 'proportion', 'newer', 'depositing', 'v ...
# Log Probability: -298130.88565239194 	Sentence: ['<s>', 'Kaida', 'artifact', 'wards', 'piece', 'Shaoguan', 'A320', 'triangles', 'disciplinary', 'thief', 'Nasrallah', 'Diarmait', 'coaster', 'Ibn', 'imaginary', 'Lowenstein', 'confirms', 'Roadblock', 'Indians', 'prescribed', 'Champlain', 'Hulke', 'periodic', 'baptistery', 'Clocks', 'bat', 'darkening', 'stimulation', 'Boom', 'D.I.C.E.', 'moor', 'Guitar', 'symptom', 'Goldhagen', 'Stefani', 'neutrino', '1985', 'supergiants', 'Bet', 'covers', 'Democratic', 'administrator', 'anyone', 'denouncing', 'announcements', 'sweet', 'came', 'Résolue', 'loop', 'subset', 'covered', 'overwhelmed', 'Cool', 'deploying', 'catch', 'Chamberlain', 'syncretized', 'goodbye', 'hypnotic', 'Acapulco', 'divides', 'Diamonds', 'realize', 'Léon', 'Captains', 'Sticks', 'squares', 'promotion', 'stereotyped', 'd4', 'bursts', 'fledging', 'cruzi', 'push', 'narrowly', 'Sociology', 'Airlines', '100th', 'grandiosity', 'Ypres', 'riff', 'station', 'Rookie', 'garrisons', 'stylistic', 'consulted', 'establishes', 'Dar', 'possibilities', 'makes', 'aboard', 'leaking', 'Cases', 'caninus', 'Orders', 'Clan', 'Guangxi', 'Hard', 'drunken', 'edition', 'Dirty', 'troff', 'Carlson', 'venerable', 'Whatever', 'plead', 'Himalayas', 'marching', 'Composition', 'Newspaper', 'Moray', 'variation', 'powers', 'bhandara', 'Żeleński', 'Richdale', 'Hooters', 'Sora', 'Vlachos', 'staff', 'Turnbull', 'deemed', 'movement', 'Airfield', 'leaf', 'ironic', 'unveiling', 'departments', 'Osiris', 'plaque', 'Protoceratopsidae', 'portions', '1593', 'spokeswoman', 'embarrass', 'tended', 'Rienzi', 'ballast', 'dragon', 'Banyuls', 'Pick', 'loved', 'atrox', 'gone', 'Bédard', 'franchises', 'smallpox', 'Osmond', 'Happy', 'Dorothy', 'telegraph', '†', 'Pity', 'Jaye', 'Otterville', 'Nebula', 'upsets', '1951', 'helping', 'infant', 'gamma', 'led', 'When', 'settlement', 'controversies', 'Americans', 'Hopkins', 'assign', '58', 'twenties', 'Academy', 'Swordians', 'unified', 'Herons', 'exploits', 'CGI', 'industrialist', 'dialect', 'presenters', 'divinely', 'grabbed', 'researchers', '98', 'c', 'interacts', '865', 'Korvettenkapitän', 'Gauls', 'Poet', 'fibers', 'reconsider', 'Riker', 'embryonic', 'cruises', 'sliced', '1744', 'Darwin', 'health', 'Gleason', 'Shaotang', 'No', 'Honours', 'exertion', 'Acropolis', '965', 'Vogue', 'gate', 'stayed', 'inflating', 'curveball', 'sportswriters', 'Landmarks', 'seat', 'capped', 'whoever', 'Ultimately', 'AMC', 'exaggerated', 'bats', 'witnessing', 'Engineers', 'Karamokho', 'constructive', 'Fitzgerald', 'issue', 'magnificent', 'Wang', 'L.A.M.B.', 'circuit', 'lateral', 'breakdown', '08', 'WAC', 'play', 'cannabis', 'fatty', 'Kenton', 'grammarian', 'Arnie', 'posts', 'lap', 'certificate', 'deleted', 'Pretty', 'mediocre', 'reliance', 'NDH', 'screams', 'Finch', 'finder', 'behind', 'oils', '257', 'Palace', 'magnates', 'Sing', 'currently', 'Islamist', 'typically', 'nymphaeum', 'Balista', 'corona', 'Synthesis', 'Basin', 'defunct', 'translated', 'private', 'Clyde', 'trawling', 'Eyed', 'boundary', 'justice', 'Leckwith', 'Narron', 'saprotrophic', 'BMNH', 'laity', 'Trail', 'Chopra', 'polynomial', 'Wehrmacht', '295', 'amendments', 'lusts', 'Bhagavata', 'Animals', 'bikini', 'accommodation', 'Proponents', 'avoiding', 'Splitsider', 'prestigious', 'Mogudu', 'covered', 'museums', 'parameters', 'reducing', 'respectively', 'accomplished', 'referendum', 'bleak', 'abortive', 'convex', 'lauding', 'heal', 'even', 'Bridlington', 'africana', 'Pattillo', 'persuaded', 'magnificent', 'scapterisci', 'Vasco', 'Schulz', 'synonymized', 'Senator', 'neurons', 'Opportunities', 'differentiated', 'Rieng', 'mated', "'re", 'Gannit', 'Rees', 'lieutenant', 'spelt', 'Models', 'Vijaya', 'incompetent', 'lake', 'gaps', 'Gibbons', 'cinema', '戦場のヴァルキュリア3', 'Hanoi', '874', 'water', 'Battles', 'animals', 'compilations', 'Mustangs', '1554', 'intrinsic', 'Hungary', 'Schauenburg', 'Walters', 'questionable', 'algorithms', 'Flag', 'Rb1', 'kingdoms', 'String', '1567', 'carbonaria', 'ambient', 'Wieselma ...
#
# --------- Corpus Perplexities ---------
# Training Set: 1101.9435880266938
# Testing Set: 912.157438593044

# %% [markdown]
# ## <font color='red'>TODO:</font> Smoothed Unigram Model [15 points]
#
# Here, you will implement each of the 4 functions described above for a <b>unigram</b> model with <b>Laplace (add-one) smoothing</b>. The probability distribution of a word is given by $P_L(w)$. This type of smoothing takes away some of the probability mass for observed events and assigns it to unseen events.
#
# In order to smooth your model, you will need the number of words in the corpus, $N$, and the number of word types, $S$. The distinction between these is meaningful: $N$ indicates the number of word instances, where $S$ refers to the size of our vocabulary. For example, the sentence <em>the cat saw the dog</em> has four word types (<em>the</em>, <em>cat</em>, <em>saw</em>, <em>dog</em>), but five word tokens (<em>the</em>, <em>cat</em>, <em>saw</em>, <em>the</em>, <em>dog</em>). The token <em>the</em> appears twice in the sentence, but they share the same type <em>the</em>.
#
# If $c(w)$ is the frequency of $w$ in the training data, you can compute $P_L(w)$ as follows:
#
# $$P_L(w)=\frac{c(w)+1}{N+S}$$
#
# <font color='green'><b>Hints:</b></font>
# * <font color='green'>You may find it convenient to make your `SmoothedUnigramModel` inherit your `UnigramModel`, and then override the function(s) that need to be changed.</font>

# %%
class SmoothedUnigramModel(LanguageModel):
    def __init__(self, trainCorpus):
        self.unigram_counts = {}
        self.total_tokens = 0
        self.vocab_size = 0  # This will store the number of unique word types

        # Training on the corpus
        for sentence in trainCorpus:
            for token in sentence:
                if token != '<s>':
                    if token not in self.unigram_counts:
                        self.vocab_size += 1
                    self.unigram_counts[token] = self.unigram_counts.get(token, 0) + 1
                    self.total_tokens += 1

    def generateSentence(self):
        generated_sentence = ['<s>']
        token = None
        while token != '</s>':
            token = self.generateToken()
            generated_sentence.append(token)
        return generated_sentence

    def generateToken(self):
        sampled_word = random.choice(list(self.unigram_counts.keys()))
        while sampled_word == '<s>':
            sampled_word = random.choice(list(self.unigram_counts.keys()))
        return sampled_word

    def getSentenceLogProbability(self, sentence):
        log_prob = 0
        for token in sentence:
            if token != '<s>':
                prob = (self.unigram_counts.get(token, 0) + 1) / (self.total_tokens + self.vocab_size)
                log_prob += math.log(prob)
        return log_prob

    def getCorpusPerplexity(self, testCorpus):
        total_log_prob = 0
        total_tokens = 0
        for sentence in testCorpus:
            total_log_prob += self.getSentenceLogProbability(sentence)
            total_tokens += len(sentence) - 1  # Subtracting for <s> token
        return math.exp(-total_log_prob/total_tokens)

# %%
if __name__=='__main__':
    sanityCheck('smoothed-unigram')
# Out:
# --- TEST: generateSentence() ---
# Test generateSentence() passed!
#
# --- TEST: getSentenceLogProbability(...) ---
# Correct log prob.: -19.0405293515 	Your log prob.: -19.0405293515 	 PASSED 	 ['<s>', 'Sonic', 'was', 'difficult', '.', '</s>']
# Correct log prob.: -115.3479413049 	Your log prob.: -115.3479413049 	 PASSED 	 ['<s>', 'By', 'the', 'Late', 'Classic', ',', 'a', 'network', 'of', 'few', '<UNK>', '(', 'few', '<UNK>', ')', 'linked', 'various', 'parts', 'of', 'the', 'city', ',', 'running', 'for', 'several', 'kilometres', 'through', 'its', 'urban', 'core', '.', '</s>']
# Correct log prob.: -108.9114348746 	Your log prob.: -108.9114348746 	 PASSED 	 ['<s>', 'Few', 'people', 'realize', 'how', 'difficult', 'it', 'was', 'to', 'create', 'Sonic', "'s", 'graphics', 'engine', ',', 'which', 'allowed', 'for', 'the', 'incredible', 'rate', 'of', 'speed', 'the', 'game', "'s", 'known', 'for', '.', '</s>']
# Correct log prob.: -54.8190029616 	Your log prob.: -54.8190029616 	 PASSED 	 ['<s>', 'Classic', 'few', 'parts', 'of', 'the', 'game', 'allowed', 'for', 'few', '<UNK>', '<UNK>', 'incredible', 'city', '.', '</s>']
# Correct log prob.: -55.8122547346 	Your log prob.: -55.8122547346 	 PASSED 	 ['<s>', 'Few', '<UNK>', 'realize', 'the', 'difficult', 'network', ',', 'which', 'linked', 'the', 'game', 'to', 'Sonic', '.', '</s>']
# Test getSentenceProbability(...) passed!
#
# --- TEST: getCorpusPerplexity(...) ---
# Correct train perp.: 41.9994393615 	Your train perp.: 41.9994393615 	 PASSED
# Correct test perp.: 39.9531928383 	Your test perp.: 39.9531928383 	 PASSED
# Test getCorpusPerplexity(...) passed!

# %% [markdown]
# Since the next sanity check trains your model on the *entire* training set, you will likely see that it is taking too long if you have inefficiences in your code. This cell is expected to run in fewer than <b>10 seconds</b>, so if it takes significantly longer than that, you should probably inspect your code for efficiency issues.

# %%
if __name__=='__main__':
    sanityCheckFullDataset('smoothed-unigram')
# Out:
# --- TEST: getSentenceLogProbability(...) ---
# Correct log prob.: -80.8423009715 	Your log prob.: -80.8423009715 	 PASSED 	 ['<s>', 'He', 'was', '<UNK>', 'at', '<UNK>', 'College', ',', 'Hobart', ',', 'and', '<UNK>', 'in', '1932', '.', '</s>']
# Correct log prob.: -174.5131424172 	Your log prob.: -174.5131424172 	 PASSED 	 ['<s>', 'Despite', 'being', 'a', 'rare', 'Grade', '9', 'player', 'on', 'the', 'senior', 'team', ',', 'he', 'was', 'one', 'of', 'the', 'Knights', "'", 'two', 'leading', 'rushers', 'that', 'year', '.', '</s>']
# Correct log prob.: -136.3181234818 	Your log prob.: -136.3181234818 	 PASSED 	 ['<s>', 'Burke', "'s", 'total', 'was', 'a', 'school', 'record', 'for', 'the', 'Big', 'Ten', 'Conference', 'Men', "'s", 'Basketball', 'Tournament', '.', '</s>']
# Correct log prob.: -225.357454098 	Your log prob.: -225.357454098 	 PASSED 	 ['<s>', 'The', 'route', 'turns', 'to', 'the', 'northeast', ',', 'passing', 'near', 'the', '<UNK>', 'Leaf', 'Lakes', 'residential', 'development', ',', 'before', 'coming', 'to', 'an', 'interchange', 'with', 'US', '322', '(', 'Black', 'Horse', 'Pike', ')', '.', '</s>']
# Correct log prob.: -719.1543898871 	Your log prob.: -719.1543898871 	 PASSED 	 ['<s>', 'Two', 'points', 'are', 'contested', ':', 'first', ',', 'whether', 'or', 'not', 'the', 'teachings', 'of', 'Scientology', 'qualify', 'as', 'a', '"', 'religion', 'or', '<UNK>', '"', '(', 'Religion', 'or', '<UNK>', ';', 'these', 'are', 'equal', 'before', 'German', 'law', ')', ',', 'and', '<UNK>', ',', 'whether', 'or', 'not', 'these', 'teachings', 'are', 'only', 'used', 'as', 'a', 'pretext', 'for', 'purely', 'commercial', 'activity', ';', 'if', 'the', 'latter', 'were', 'the', 'case', ',', 'this', 'would', 'most', 'likely', 'imply', 'that', 'Scientology', 'would', 'not', 'qualify', 'for', 'protection', 'as', 'a', '"', 'religious', 'or', '<UNK>', 'community', '"', '(', '<UNK>', 'oder', '<UNK>', ')', 'under', 'Article', '4', 'of', 'the', 'German', 'constitution', ',', 'which', 'guarantees', 'the', 'freedom', 'of', 'belief', ',', 'religion', 'and', '<UNK>', '.', '</s>']
# Correct log prob.: -236.6682968913 	Your log prob.: -236.6682968913 	 PASSED 	 ['<s>', 'He', 'immediately', 'ran', 'into', 'a', 'problem', ':', 'the', 'South', 'Carolina', 'troops', '(', 'militia', 'or', 'the', 'colonial', 'regiments', ')', 'were', 'not', 'on', 'the', 'Continental', 'line', ',', 'and', 'thus', 'not', 'formally', 'under', 'his', 'authority', '.', '</s>']
# Correct log prob.: -126.1965419509 	Your log prob.: -126.1965419509 	 PASSED 	 ['<s>', 'One', 'of', 'them', 'was', 'a', 'bodyguard', 'who', 'was', 'present', 'at', 'the', 'concert', 'but', 'did', 'not', 'see', 'the', 'fall', '.', '</s>']
# Correct log prob.: -47.4369338195 	Your log prob.: -47.4369338195 	 PASSED 	 ['<s>', '<UNK>', 'was', 'relieved', 'on', '17', 'May', '.', '</s>']
# Correct log prob.: -47.7692144935 	Your log prob.: -47.7692144935 	 PASSED 	 ['<s>', 'US', 'Off', 'The', 'Planet', '!', '</s>']
# Correct log prob.: -138.542462715 	Your log prob.: -138.542462715 	 PASSED 	 ['<s>', 'The', 'difficulty', 'stems', 'from', 'the', 'relative', 'over', '@-@', 'stabilization', 'of', 'the', '<UNK>', 'cation', 'by', 'electron', 'donation', ',', '<UNK>', '<UNK>', '.', '</s>']
# Test getSentenceProbability(...) passed!
#
# --- TEST: getCorpusPerplexity(...) ---
# Correct test perp.: 881.6105352831 	Your test perp.: 881.6105352831 	 PASSED
# Test getCorpusPerplexity(...) passed!

# %%
if __name__=='__main__':
    runModel('smoothed-unigram')
# Out:
# --------- 5 sentences from your model ---------
# Log Probability: -12330.09580950968 	Sentence: ['<s>', 'Merrifield', 'Veerashaiva', 'Choir', 'biologist', 'Brandt', 'dumped', 'rewritten', 'compile', 'McCall', 'dredged', 'Region', 'impacting', 'pulpit', 'forward', 'aircraft', 'conversations', 'Olav', 'varieties', 'Natalie', 'Free', 'Grove', 'HaMifratz', 'preyed', 'stirring', 'Kepler', 'bivouac', 'Demolition', 'criticizing', 'Den', 'Mantell', 'Myth', 'Demolition', 'goals', 'Ke', 'Bedell', 'Kanye', 'murals', '″', 'Torchwood', 'tis', 'residing', 'photos', 'Foxes', 'Hibari.Ch.', 'portable', 'Short', 'UTC', 'Notes', 'wardrobe', 'lamps', 'Madsen', 'lirpa', 'dream', 'Bengali', 'fills', '1161', 'explanations', '2019', 'Highlands', 'Lacey', 'Judgment', 'Aegean', 'planted', 'Deva', 'pave', 'organizer', 'Wine', 'ibotenic', 'fortune', 'Curtain', 'scholastic', 'Pro40', 'competent', 'clause', 'lectures', 'ambassadorial', 'Treason', 'Bulgarian', 'tertiary', 'staff', 'sortie', 'Sustainability', 'accusations', 'French', 'reaffirmed', 'YouTube', 'counteract', 'gentle', 'Sophie', 'Asuka', 'promotes', 'Atlas', 'Candy', 'Lions', 'gather', 'Nicaea', 'stem', 'Easy', 'configuration', 'unleashed', 'Borderers', 'Yanjing', 'customers', 'sporting', 'missed', 'refused', 'meld', 'boating', 'Croatian', 'metastable', 'flamethrower', 'stomach', 'Zweig', 'Toward', 'noitulovE', 'lignotuber', 'Shinji', 'suppress', 'Rooms', 'quickly', 'Matam', 'detectable', 'Investment', 'archived', 'Vega', 'moralitas', '1624', 'determining', 'clone', 'Jinx', 'recovering', 'disposal', 'reliable', 'HMCs', '1968', 'rectified', 'disks', 'gains', 'Grosmont', 'Puebla', 'II', 'automatic', 'irony', 'asked', 'Eddy', 'purity', 'Alaska', 'Frontier', '1766', 'ornithologists', 'perxenate', 'Superintendent', 'silent', 'preserving', 'curved', 'Mfume', 'Aylwin', "'elkhunu", '109', 'deactivated', 'verses', 'Italians', 'materialize', '667', 'Saint', 'master', 'Fay', 'ESPN', 'directly', 'indicating', 'Sayid', 'seeks', 'Aquila', 'reviving', 'Sharif', 'Wu', 'Lover', 'somewhat', 'doubles', 'enzymes', 'Ghats', 'filmmaker', 'anthem', 'Siberia', 'Own', 'supplementary', 'files', 'voting', 'plated', 'pirates', 'liberation', 'Robby', 'Duirinish', 'Originally', 'parrot', 'Twelve', 'Christianisation', 'queries', 'Countries', 'Dawson', 'olives', 'stechowi', 'Waller', 'helpful', 'established', 'idealist', 'stoic', 'Slavonia', 'Caxton', 'Jobs', 'superstitious', 'stela', 'lifeguard', 'Michoacán', 'Bode', 'Willis', 'Describing', 'Down', 'farinaceous', 'Musicnotes.com', 'Help', 'Re', 'looming', 'Technical', 'Balista', 'Whole', 'Iain', 'dominate', 'server', 'Goodwin', 'competitor', 'GHQ', 'ghats', 'games', 'effectiveness', 'bout', 'Roy', 'sidekick', 'globular', 'baptized', 'rekindle', 'imparted', 'Feast', 'tracts', 'prohibiting', 'Barbarian', 'antibiotic', 'Litigators', 'denoted', 'mammalian', 'prosecutors', 'juvenile', 'forgery', 'Tasmanian', 'topmost', 'periods', 'retro', 'Aquilops', 'alabaster', 'Hayhurst', 'Batholith', 'importantly', 'Remains', 'Chapat', 'commendation', 'Association', 'Morhange', 'Kevin', 'insists', 'Boswell', 'transfer', 'Lands', 'pulmonary', 'globular', 'recast', 'Tehran', 'Europium', 'dos', 'Gratitude', 'Lansing', 'Sáenz', 'Opposition', 'centers', 'advance', 'classified', 'denies', 'Lalande', 'Immortals', 'Inspiration', 'both', 'NS', 'landings', 'Funerary', 'Haydn', 'notorious', 'item', 'dealing', 'regardless', 'recent', 'eSports', 'regional', 'Ticket', 'tuned', 'Tang', 'Ante', 'removal', 'Pliny', 'upsetting', 'enthusiasm', 'Brockman', 'Yokoi', 'prosthetic', 'slider', 'twist', 'astronomer', 'recommending', 'Mint', 'depicts', '015', 'wreck', 'defend', 'officiating', 'tubular', 'scripted', 'Salford', 'Lincoln', 'Crooked', 'regal', 'unrecorded', 'recurring', 'Kick', 'Helms', 'gym', 'vassals', 'BET', 'garrison', 'sacraments', 'Cecil', 'knot', 'Burma', 'laps', 'fulfill', 'Madero', 'Zhou', 'Alyssa', 'Claims', 'Angola', 'Yokozuna', 'empties', 'caption', 'pouches', 'Klingons', 'Spartans', 'Fe', 'gendered', 'winged', 'bolstered', 'Stones', 'budding' ...
# Log Probability: -47425.30402033108 	Sentence: ['<s>', 'prematurely', 'sedentary', 'commencing', 'dwellers', 'rafts', 'Glosserman', 'Fraternal', 'contends', 'Airspace', 'Rockets', 'Scranton', 'allegation', 'plans', 'clinical', 'Alonso', 'elaborately', 'karyopherins', 'Buenos', 'Cliff', 'Troy', 'Newsted', 'Zzap', 'Used', 'stable', 'textbook', 'bloodline', 'infinite', 'Keeper', '1637', 'grocery', 'recruits', 'during', 'elevator', 'flop', 'sight', 'athlete', 'eroding', '1648', 'Personality', 'indigenous', 'Swiss', 'critically', 'weary', '254', 'Pontprennau', 'unjustly', 'BB', 'insulted', 'Levi', 'modifications', 'Runway', 'lust', 'unnumbered', 'Wilbur', 'streaked', 'Włodzimierz', 'Elk', 'morality', 'sleeping', '486', 'project', 'Pupils', 'Corythosaurus', 'Brutus', 'trawls', 'skimpy', 'offerings', 'Selo', 'strengthens', 'some', 'Inherent', 'Published', 'elderly', 'Cenozoic', 'Leptoceratopsidae', 'Ain', 'tricks', 'Amun', 'Symphonic', 'artillery', 'One', 'kittens', '1682', '502nd', 'Vegas', '1650', 'Jamal', 'wooden', 'buoys', 'placement', 'registers', 'unmarked', 'apex', 'hair', 'destroying', 'practical', 'shorten', 'Sara', 'glamour', 'ejected', 'Divisional', 'bulls', 'Disaster', 'Creek', 'shouting', '502', 'commemorate', 'vignettes', 'singer', 'knighted', 'cooled', 'forelimbs', 'Loughborough', 'Potential', 'Prophet', 'lineman', 'pines', 'nakedness', 'divides', 'interacted', '1846', 'mac', 'Semitic', '1194', 'Scale', 'lifestyle', 'Sonate', 'Maryada', 'tag', 'cheats', 'Alton', 'spiral', 'Penelope', 'philosophers', 'diplomacy', 'Biringuccio', 'hull', 'McCarthy', 'Fitz', 'Facing', 'Coupled', 'plotting', 'Alun', 'splits', 'glowing', 'anomaly', 'within', 'rDNA', 'Mauzac', 'regard', 'Indus', 'Shuttle', 'electropop', 'Weston', 'Partial', 'Cálidas', 'replacement', 'NYC', 'Sari', 'housing', 'Wellington', 'enterprise', 'progressed', 'MP', 'armored', 'agaric', 'Andes', 'Martyn', '878', 'resigned', 'petrol', "'in", 'Poison', 'blessing', 'rank', 'auditioning', 'Mexico', 'Rita', 'alluded', 'Turkish', 'Madsen', 'bidders', 'Memories', 'excitement', 'Broadest', 'restrictive', 'Jifna', 'stadia', 'Stewart', 'independence', 'nucleolar', 'reactors', 'multipurpose', 'shipwrecked', 'beginning', 'Rules', 'cockroaches', 'resent', 'intrinsically', 'Trinity', 'ver', 'Glenelg', 'shown', 'reactive', 'Tapes', 'guttural', 'Aside', 'Pitcher', 'Strange', 'dubbed', 'nationwide', 'section', 'pleasures', 'mornings', 'Engineering', 'advantages', 'consultants', 'lopsided', 'pédalier', 'dishonest', 'Feigenbaum', 'Hathershaw', 'guitarists', 'brink', 'Minginish', 'Braun', 'bogged', 'Campbeltown', '5th', 'Farmhouse', 'foliage', 'prosecution', 'bacterial', 'Inspiration', 'cloudy', '620', 'amenities', 'Car', 'mutations', 'Halley', 'Mann', 'Marilyn', 'Teresa', 'Perón', 'Our', 'Freaks', 'Vega', 'umpires', 'renders', 'Aviv', 'Rio', 'benevolent', 'serve', 'EMI', 'relaxing', 'Kooper', 'stone', '030', 'Poehler', 'excess', 'DRS', 'setting', '650', 'comedies', 'Dudleys', 'Carbuncle', 'Waverly', 'constituents', 'salient', 'Kosovo', 'Riddick', 'Campanian', 'demolished', 'Boletales', 'Galloway', 'Worthing', 'Ninian', 'sightings', 'feather', 'registration', 'Antilles', 'Zeus', 'Continuing', 'Intent', 'sulfur', 'Shin', 'km', 'prosthetic', 'Terminal', 'Dooley', 'ridge', 'Koh', 'monospaced', 'definitely', 'nasals', 'Lynn', 'mechanics', 'TFG', 'reactivated', 'lights', 'hackers', 'Syriac', 'promenade', 'wildlife', 'Development', 'dinosaur', 'Chevalier', 'plaza', 'broke', 'piles', 'tolls', 'Bruyn', 'abutments', 'Hancock', '...', 'natural', 'kelp', 'establishing', 'Enemy', 'outreach', 'Île', 'FIBA', 'overlooked', 'Journalists', 'such', 'audience', 'censor', 'Industrial', 'puritan', 'Archaeology', 'dimension', 'Tide', 'carelessly', 'representatives', 'bassist', 'Poison', 'settlement', 'Etingoff', 'active', 'progressive', 'basic', 'sank', 'relationship', 'Fellow', 'Zumárraga', 'caesarea', 'Annapurna', 'scapterisci', 'Bianco', 'systemic', 'distinguish', 'overpasses', 'Iguanodon', 'inches', 'Narves ...
# Log Probability: -910843.9491506692 	Sentence: ['<s>', 'Clean', 'Scapteriscus', 'linguists', 'MLA', 'loyalist', 'monuments', 'AL', 'done', 'writings', 'Ascot', 'dreams', 'Cheers', 'standby', 'staples', 'Karnow', 'angered', 'resurrect', 'Jennings', 'analyzed', 'mourning', 'uncommon', 'disbanding', 'inflating', 'Compton', 'Management', 'junior', 'manufacturer', 'worries', 'flaxen', 'Mesolithic', 'reanalysis', 'photographing', 'Wieselman', 'californicus', 'Male', 'mintage', 'strings', 'Astoria', 'pitches', 'billionaire', 'Corporate', 'obsession', 'Lindelof', '167', 'familial', 'Peruvian', 'rematch', 'Danja', 'Symposium', 'maintains', 'setup', 'Leavis', 'Grube', 'subtext', 'rhythmic', 'cruises', 'partially', 'images', 'Goodison', 'Manners', 'reconstructions', 'cybernetic', 'implies', 'longstanding', 'prepared', 'Chinese', 'competitor', 'reagents', 'willingness', 'mythical', 'ppm', 'Romero', 'visibility', 'centre', 'estranged', 'Ultimately', 'Brutus', 'Donaldson', 'Dot', 'Limited', 'Reserves', 'players', 'shares', 'bipedal', 'Medieval', 'Danes', 'setup', 'comforts', 'Antonescu', '70s', 'expecting', 'fill', 'amalgamation', 'Lithuanian', 'screened', '1744', 'ringtone', 'Shaanxi', 'slipping', 'Stupnitsky', 'brightest', 'cousin', 'Radio', 'guerre', 'formatting', 'Banadir', 'oblivion', 'Forever', 'Detachment', 'pilot', 'Mothers', 'resisting', 'reduced', 'Consequently', 'inaugural', 'Wife', 'Leo', 'Palicki', 'rolls', 'Text', 'LeChuck', 'defines', 'revolution', 'Jacob', 'fallen', 'cast', 'shouldn', 'displaced', 'consumer', 'Vengeur', 'seaplanes', 'Cyrus', 'anecdotes', 'Michelin', 'Kir', 'undergone', 'expiring', 'relocated', 'Halloween', 'dripping', 'sanctuaries', 'Internal', 'Skye', 'Sociology', 'lodgepole', 'perfumes', 'missing', 'protected', 'schoolhouse', 'Tourism', 'Partnership', 'quickly', 'Dad', 'bar', 'farmers', 'McAllister', 'handed', 'Cure', 'Bashir', 'Haas', 'downfall', 'appropriation', 'apologizes', 'maximum', 'joystick', 'Queen', 'Dagenham', 'Priory', 'McCoy', 'floated', 'Varina', 'Silverstone', 'cinemas', 'novels', 'reprising', 'rejoin', 'advocacy', 'supporting', 'womanhood', 'Crowley', 'graduation', 'Synagogue', 'reconstructed', 'diversionary', 'dunams', 'Ācārya', '228', 'abruptly', 'pounds', 'giant', 'described', 'tails', 'Zionism', 'axial', 'exactly', '18th', 'Boyd', 'fulfilled', 'finally', 'everyone', 'tones', 'error', 'Egitto', 'statues', 'Devlin', 'Show', 'theatre', 'Grays', 'Carnation', 'Covent', 'Returning', 'shakedown', 'Coriolis', 'Kern', 'pretended', 'hagiography', 'Legal', 'radioactive', 'Berle', 'inspiring', 'houses', '1627', 'Kartik', 'Vandernoot', 'Notwithstanding', 'Greatest', 'disaster', 'NC', 'cowardice', 'Fisherman', 'Presbyterians', 'Johannesburg', 'Bowden', 'ask', 'Hämeenmaa', 'fatty', 'Theme', 'intertwine', 'Novel', 'centralised', 'myths', 'Lake', 'compete', 'commentary', 'Konrad', 'Bianjing', 'Dinosaur', 'Dura', 'LSU', 'turnpikes', 'transmitting', 'Nice', 'conveys', 'Lastly', 'sprinters', 'sympathetic', 'revision', 'adoptive', 'interlude', 'Cahill', 'kick', 'advising', 'rage', 'McEnroe', 'refinery', 'galactic', 'fits', 'Othniel', 'guys', 'films', 'incapacitated', 'inhaled', '2002', 'manning', 'Winds', 'sure', 'Surface', 'Ramon', 'spokesperson', 'Apu', 'onward', 'merger', 'Steven', 'field', 'contractors', 'Queen', 'Santana', 'seductive', 'Warrior', 'exemplified', 'depressed', 'Kerr', 'Weapons', 'Dawson', '1271', 'nursery', 'fertility', 'paler', 'accuses', 'postwar', 'deducted', 'relaunched', 'toy', 'richly', 'Colombo', 'mathematicians', 'Horgan', 'pump', 'managed', 'Aleppo', 'Antoni', 'thunderstorm', 'crevice', 'unexpectedly', 'suits', 'errors', 'ignite', 'muscles', 'responds', 'Hepburn', 'leverage', 'racism', 'Doofenshmirtz', 'reverting', 'waves', 'Cyanide', 'annum', 'booking', 'summarily', 'DS9', 'structured', 'ecosystem', 'Clemson', 'Kiryat', 'Ghat', 'comparison', 'generates', 'brown', 'lobster', 'Technologies', 'suppression', 'broadcast', 'Taff', 'success', 'withdraw', 'intimately', 'Common', 'jersey ...
# Log Probability: -679821.4436339276 	Sentence: ['<s>', 'longs', 'essay', 'Devils', 'Depictions', 'reconcile', '138', 'ambition', 'Mbaruk', 'hire', 'budding', 'EU', '1860', 'duff', 'firsts', 'Dunster', 'paper', 'Boot', 'dye', 'yacht', 'chooses', 'ceded', 'camphor', 'gravitational', 'rack', 'distributes', 'leadership', 'GPa', 'cleared', 'Blanc', 'Sewell', 'option', 'Loves', 'Sonia', 'Verdi', 'indirect', 'exerted', 'uterine', 'Y', 'Diamonds', 'aplacental', 'Suryanarayana', 'officer', 'Dubois', 'wished', 'embody', 'Marck', 'intensely', 'hunger', 'Afterward', 'Turks', 'candy', 'counterparts', 'point', 'democracy', 'Based', '1813', 'covert', 'merchant', 'clone', 'Rhode', '1216', 'bonnet', 'Makes', 'palate', 'Whalers', 'Mueller', 'subsumed', 'coldest', 'kitsune', 'coaxial', '1216', 'large', 'inclusive', 'stingrays', 'Spotnitz', 'hit', 'Ulster', 'Marsh', 'rocket', 'Elinor', 'Collection', 'Zapata', 'fans', 'echoing', 'body', 'Rose', 'Monteith', 'rpg', 'Tetris', 'repatriation', 'Helga', 'substitute', 'logs', 'Parachute', 'infertile', 'tent', 'relapse', 'streak', 'modernisation', 'QC', 'upheavals', 'Parsons', 'Labour', 'speculate', 'Twenty20', 'overcrowding', 'prowess', 'Wendell', 'pivotal', 'Miss', 'scavengers', 'hurricanes', 'vulgar', 'interviews', 'favorites', 'Fédération', 'symptoms', 'doubling', 'To', 'instrumentalist', 'activates', 'president', 'tends', 'embarking', 'breathy', 'destiny', '725', 'honorable', 'Fairies', 'discount', 'Amanita', 'Romanesque', 'recover', 'Darvin', 'Indira', 'proportions', 'refreshingly', 'Valerian', 'cameos', 'Ptolemy', 'statue', 'struggling', 'Spears', 'sprawling', '495', 'officials', 'centerpiece', 'Reflections', 'Mackinac', 'special', 'curtain', 'Free', 'Ethiopia', 'fixtures', 'general', 'captured', '172', 'unremarkable', 'showcasing', 'strikeout', 'Sinatra', 'arena', 'Christmastime', 'Cobain', 'Svay', 'procedural', 'Nigel', 'Gale', 'Gould', 'Analyses', 'conduct', 'broadcasters', 'favours', 'Parmenter', 'wealthiest', 'Woodsboro', 'Ennis', 'Vanstabel', 'Splash', 'analysis', 'picnic', 'fangs', 'devotion', 'action', 'heath', 'confirm', 'enters', 'flank', 'Hayley', 'sword', 'unimpeded', '2004', 'airports', 'undivided', 'Message', 'substances', 'LED', 'erroneous', 'butter', 'Creighton', 'surface', 'hastily', 'turns', 'symmetry', 'acceded', 'Aimé', 'monism', 'try', 'orphaned', 'demonstrated', 'carpets', 'outfitting', 'adaptable', 'nightlife', 'every', 'boulevard', 'harassed', 'bushes', 'electors', 'interphase', 'Manufacturers', 'Firefly', 'revoked', 'watercolors', 'Duchy', 'conformity', 'greys', 'symmetry', 'filling', 'lent', 'ICC', 'centric', 'micrometres', 'nominations', 'Crime', '52nd', 'residences', 'JAR', 'Marriott', 'archived', 'motions', 'migration', 'bullied', 'means', 'Rule', 'Sega', 'saved', 'Homarinus', 'Proceeding', 'ecstasy', 'Kildare', 'Lafitte', 'Garza', 'labor', 'Birch', 'Fans', 'taping', 'HDZ', 'whitewashed', 'solar', 'Hema', 'coalition', 'provider', 'carpenters', 'დ', 'Dorset', 'summarised', '770', 'Ion', 'venomous', 'Curt', 'Colonization', 'Neoscapteriscus', 'dots', 'Wisniewski', 'champions', 'collaboration', 'Reflections', 'obviously', 'Alamos', 'creeps', 'delivered', 'density', 'vary', 'dealership', 'beaches', 'Ceratosaurus', 'ambition', 'Pleasure', 'rancid', 'render', 'Sherman', 'Levine', '283', 'retardants', 'Ortiz', 'commended', 'façade', 'Marismeño', 'clearing', 'reestablish', 'sloped', 'happen', 'Kahne', 'amassed', 'professional', 'assured', 'Naraharitirtha', 'biographies', 'Supplement', 'Waterfall', 'ought', 'stomach', 'e5', 'consequence', 'abruptly', 'kDa', 'whereupon', 'Originally', 'late', 'corps', 'Then', 'Asiatic', 'flute', 'Onondaga', 'Jodidio', 'autoharp', 'Croydon', 'Surfer', 'Mauryas', 'Zaitsev', 'fit', 'bootleg', 'Unnatural', 'tombs', 'Fender', 'slabs', 'FAA', 'special', 'Yugoslavia', 'Scottie', 'Angelou', 'Factor', 'Barrow', 'simplistic', 'Anglesey', 'KGUL', 'Firefly', 'mi', 'Cautionary', 'Writers', 'Worthing', 'intoxicated', 'Gashmu', 'films', 'proportionate', 'unwitti ...
# Log Probability: -16376.004424650066 	Sentence: ['<s>', 'squads', 'Hirosaki', 'biplane', 'all', 'burns', 'primaries', 'Browns', 'Levee', 'purple', 'Absorption', 'Rosebery', 'Soundgarden', 'Shaft', 'include', 'RPG', 'Bill', 'South', 'risk', 'Ode', 'night', 'independent', 'NHS', 'Corpus', 'charts', 'stabbed', 'Mengden', 'Poeti', 'unnatural', 'Fredericksburg', 'Mesolithic', 'subfossil', 'Moderate', 'Manitoba', 'atom', 'Arkadelphia', 'flea', 'porters', 'cloud', 'stylized', 'prequel', 'on', 'groves', 'exquisite', 'commandant', 'safeguard', 'Che', 'Dvaita', 'Raphael', 'Ignace', 'Professor', 'Scholars', 'McKean', 'manipulates', 'doubt', 'Nuzman', 'cartridges', 'Union', '380', '361', 'expectation', 'Until', 'magazines', 'Chambers', 'Function', 'Text', 'Meet', 'Aka', 'reprised', 'kilogram', '·', 'wartime', 'deferred', 'botanist', 'expound', 'Harvey', 'denominations', 'weakest', 'understated', 'IATA', 'Velocetron', 'sailor', 'Yo', '1221', 'Music', 'positioning', 'Winters', 'distant', 'epics', 'Fire', '1194', 'Mu', 'taunts', 'Pelican', 'borrowed', 'totaled', '1622', 'levy', 'steamer', 'continual', 'intensively', 'hysterical', 'ecliptic', 'Runaway', 'Swords', 'Alphonse', 'Publications', 'herders', 'citizens', 'discreetly', 'coolness', 'kinship', 'groundwater', 'Birth', 'copy', 'platformer', 'Dorn', 'votive', 'themselves', 'Scipion', 'Hatteras', 'pallium', 'abbreviations', 'Malcom', 'Eurasian', 'Lourenço', 'goddess', 'sure', 'particles', 'Egitto', 'technique', '1646', 'bypassed', 'NMR', '[', 'Awakening', 'Plugge', '1754', 'Deadwood', 'submit', 'leveled', 'polling', 'puddings', '403', 'degenerate', 'Centrosaurus', 'Humpty', 'guy', 'Chrysler', 'Benton', 'apoptotic', 'hurling', 'inform', 'Morey', 'Newport', 'resume', 'tribute', 'Casablanca', 'strands', 'elk', 'British', 'refreshingly', 'Ösel', 'lovers', 'marsh', 'MC', 'progresses', 'wary', 'craftsmanship', 'nuts', 'amateurism', 'Specification', 'Hubble', 'vicinity', 'K.', 'immortal', 'grandfather', 'willows', 'Stolac', 'SuperWASP', 'ornithopod', 'Marseille', 'creation', 'Haitian', 'species', '1848', 'censorship', 'enclosing', 'Randall', 'impaired', 'Officers', 'toyline', 'Ludacris', 'backward', 'over', 'republics', 'faintest', 'nucleolus', 'Worthing', 'Leukemia', 'portable', 'diodes', 'Seven', 'includes', 'Anders', 'Mercer', 'punishment', 'Dixie', 'Cameo', 'Pola', 'suplex', 'nakedness', 'Hardcover', '..', 'Alone', 'Gudbrandsdalen', 'peptides', 'Lwów', 'streetcars', 'Faces', 'Children', 'scar', 'Trends', 'excerpt', 'sufficiently', 'settlements', 'refuse', 'Kids', 'Creed', 'distracted', 'Lewes', 'Station', 'HitFix', 'indenture', 'Llangaffo', 'absolute', 'largest', 'canons', 'beginnings', 'Katy', 'Jifna', 'Mama', 'electoral', 'Weyden', 'archbishopric', 'Hibbett', 'rig', 'Gillespie', 'heretico', 'defeating', 'download', 'Gutierrez', 'V', 'Let', 'Orion', 'Tuxpan', 'cooperated', 'program', 'frontage', 'briefly', 'Gives', 'Directed', 'precision', 'ideals', 'RZA', 'prematurely', 'viewer', 'overlaid', 'Heroes', 'an', 'Dynamic', 'first', 'ethic', 'lands', 'Busqué', 'Crew', 'systemic', '1137', 'allegation', 'Filmed', 'moisture', 'Ranges', 'Grand', 'Semaphore', 'Reg', 'Collector', 'driver', 'Ilan', 'plate', 'Perugia', 'noted', 'Trenchard', 'mimicked', 'proud', 'squares', 'Trinity', 'flat', 'sited', 'beneficial', 'oak', 'YouTube', 'purchases', 'Subic', 'serviced', 'Bayeux', 'L.A.M.B.', 'retelling', 'grew', 'Serious', 'ballroom', 'Universal', 'ride', 'Kesteven', 'flattened', 'Morrow', 'downturn', 'aircraft', 'dredged', 'Vanessa', 'triangles', 'Onondaga', 'whim', 'purchased', 'Inquiry', 'Bering', 'you', 'thumping', 'Muhammed', 'paintings', 'vacancies', 'favorite', 'avenge', 'Felix', 'static', 'NY', 'ballroom', 'faulty', 'Gibbons', 'nucleolar', 'strengthening', 'exterior', 'occult', 'newspapers', 'everglades', 'sulfoxonium', 'sync', 'infamous', 'overthrow', 'serve', 'cal', 'regional', 'Seamus', 'bassline', 'cooperated', 'Shuttle', 'Corpus', 'Cadw', 'sequenced', 'evidently', 'quote', 'Probably', 'greater', 'c ...
#
# --------- Corpus Perplexities ---------
# Training Set: 1103.0243317444856
# Testing Set: 914.472450228316
