# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### PCA on Simple Numpy Array Data Done in Class

# %%
A = np.array([[4, 3, 1], [4, 1, 1], [2, 3, 4]])
print(A)
# Out:
# [[4 3 1]
#  [4 1 1]
#  [2 3 4]]

# %%
t = A.transpose()
t
# Out:
# array([[4, 4, 2],
#        [3, 1, 3],
#        [1, 1, 4]])

# %%
at = np.matmul(A, t)
at
# Out:
# array([[26, 20, 21],
#        [20, 18, 15],
#        [21, 15, 29]])

# %%
w, v= np.linalg.eig(at) # drop one column
print(v)
print(w)
# Out:
# [[-0.62245567 -0.69560878 -0.35871629]
#  [-0.48796026  0.70326586 -0.51702216]
#  [-0.61191807  0.14678408  0.77718126]]
# [62.32304429  1.34852432  9.32843139]

# %%
w.sort(axis=-1)
print(w)
w[1:]
# Out:
# [ 1.34852432  9.32843139 62.32304429]
# array([ 9.32843139, 62.32304429])

# %%
FVectors = np.delete(v, 2, axis=1)
print(FinalSelectedVectors)
# Out:
# [[-0.62245567 -0.69560878]
#  [-0.48796026  0.70326586]
#  [-0.61191807  0.14678408]]

# %%
AVectors = np.insert(FVectors,[2], [[0]], axis = 1) 
print(AppendedVectors)
# Out:
# [[-0.62245567 -0.69560878  0.        ]
#  [-0.48796026  0.70326586  0.        ]
#  [-0.61191807  0.14678408  0.        ]]

# %%
print(A.shape, AVectors.shape)
# Out:
# (3, 3) (3, 3)

# %%
PCA=np.matmul(A, AVectors)

print(PCA)
# Out:
# [[-4.56562153 -0.52585345  0.        ]
#  [-3.589701   -1.93238517  0.        ]
#  [-5.1564644   1.30571634  0.        ]]

# %% [markdown]
# ### Iris Dataset PCA

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# %%
# Load a sample dataset (Iris dataset in this case)
data = load_iris()
X = data.data

# Standardize the data (centering and scaling)
mean = np.mean(X, axis=0)
std_dev = np.std(X, axis=0)
X = (X - mean) / std_dev

# %%
# Initialize PCA with the desired number of components
n_components = 2
pca = PCA(n_components=n_components)

# Fit and transform the data
X_pca = pca.fit_transform(X)

# %%
# Principal components
principal_components = pca.components_

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Variance explained by each component
explained_variance = pca.explained_variance_

# %%
print(explained_variance)
# Out:
# [2.93808505 0.9201649 ]

# %% [markdown]
# ### PCA on Titanic Data

# %%
df = pd.read_csv("Train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dt = df.transpose()
dt
# Out:
#                                  0    \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                            1    \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
x = df.mean()
x = list(x)
x
# Out:
# C:\Users\Bahadur\AppData\Local\Temp\ipykernel_2836\1678994915.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   x = df.mean()
# [446.0,
#  0.3838383838383838,
#  2.308641975308642,
#  29.69911764705882,
#  0.5230078563411896,
#  0.38159371492704824,
#  32.204207968574636]

# %%
n_components = 1
pca = PCA(n_components=n_components)

# Fit and transform the data
X_pca = pca.fit_transform([x])
# Out:
# C:\Users\Bahadur\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\decomposition\_pca.py:525: RuntimeWarning: invalid value encountered in divide
#   explained_variance_ = (S**2) / (n_samples - 1)

# %%
# Principal components
principal_components = pca.components_

# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_

# Variance explained by each component
explained_variance = pca.explained_variance_

# %%
print(explained_variance)
# Out:
# [nan]
